# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-04-29 04:03:37.706668: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777435417.899600      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777435417.951156      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777435418.381842      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777435418.381874      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777435418.381877      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777435418.381879      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'neutral': 7215, 'happy': 7215, 'sad': 7215, 'surprised': 7215, 'angry': 7215, 'fearful': 7215, 'disgusted': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    # width_shift_range=0.1,
                                    # height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5771, 'disgusted': 5768, 'angry': 5776, 'neutral': 5776, 'sad': 5767, 'surprised': 5773, 'happy': 5773}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # Modeling

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1
        layers.Conv2D(16, (5, 5), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (5, 5), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),

        # Block 2
        layers.Conv2D(64, (5, 5), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(128, (5, 5), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 4
        layers.Conv2D(256, (5, 5), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Full Connected
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(len(classes), activation='softmax') # Mengikuti jumlah class kamu
    ])
    
    return model

model = build_final_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1777435680.359800      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 16)     │         1,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 32)     │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 128)    │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 256)      │       819,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,277,479 (8.69 MB)
#  Trainable params: 2,275,463 (8.68 MB)
#  Non-trainable params: 2,016 (7.88 KB)

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN_4Block"

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_'+model_name+'.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# 1. Checkpoint: Simpan model terbaik secara otomatis
checkpoint = ModelCheckpoint(
    'best_emotion_model.keras', # Gunakan ekstensi .keras
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 2. Learning Rate Scheduler: Menurunkan LR jika akurasi stagnan
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=0.00001,
    verbose=1
)

# Define the callback
early_stopping = EarlyStopping(
    monitor='val_loss',      # Metric to monitor
    patience=5,              # Number of epochs with no improvement
    restore_best_weights=True, # Restores model weights from the best epoch
    verbose=1
)

# Gabungkan callbacks
callbacks_list = [checkpoint, lr_scheduler, early_stopping]

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777435686.151849     156 service.cc:152] XLA service 0x7fe1e8004670 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777435686.151888     156 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1777435686.932632     156 cuda_dnn.cc:529] Loaded cuDNN version 91002
#    6/1263 ━━━━━━━━━━━━━━━━━━━━ 35s 28ms/step - accuracy: 0.1155 - loss: 3.1057
# I0000 00:00:1777435693.477172     156 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2245 - loss: 2.2875
# Epoch 1: val_accuracy improved from -inf to 0.37046, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 70s 47ms/step - accuracy: 0.2245 - loss: 2.2873 - val_accuracy: 0.3705 - val_loss: 1.6691 - learning_rate: 0.0010
# Epoch 2/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3827 - loss: 1.6042
# Epoch 2: val_accuracy improved from 0.37046 to 0.39174, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.3827 - loss: 1.6041 - val_accuracy: 0.3917 - val_loss: 1.6893 - learning_rate: 0.0010
# Epoch 3/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4628 - loss: 1.4158
# Epoch 3: val_accuracy improved from 0.39174 to 0.53638, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.4628 - loss: 1.4158 - val_accuracy: 0.5364 - val_loss: 1.2272 - learning_rate: 0.0010
# Epoch 4/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5069 - loss: 1.3010
# Epoch 4: val_accuracy improved from 0.53638 to 0.55064, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5069 - loss: 1.3010 - val_accuracy: 0.5506 - val_loss: 1.1828 - learning_rate: 0.0010
# Epoch 5/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5369 - loss: 1.2352
# Epoch 5: val_accuracy did not improve from 0.55064
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5369 - loss: 1.2352 - val_accuracy: 0.5396 - val_loss: 1.2356 - learning_rate: 0.0010
# Epoch 6/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5611 - loss: 1.1742
# Epoch 6: val_accuracy improved from 0.55064 to 0.60608, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5611 - loss: 1.1742 - val_accuracy: 0.6061 - val_loss: 1.0585 - learning_rate: 0.0010
# Epoch 7/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5721 - loss: 1.1386
# Epoch 7: val_accuracy did not improve from 0.60608
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5721 - loss: 1.1386 - val_accuracy: 0.5147 - val_loss: 1.2641 - learning_rate: 0.0010
# Epoch 8/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5801 - loss: 1.1057
# Epoch 8: val_accuracy did not improve from 0.60608
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5801 - loss: 1.1057 - val_accuracy: 0.5937 - val_loss: 1.0836 - learning_rate: 0.0010
# Epoch 9/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5939 - loss: 1.0719
# Epoch 9: val_accuracy improved from 0.60608 to 0.63380, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5939 - loss: 1.0719 - val_accuracy: 0.6338 - val_loss: 0.9699 - learning_rate: 0.0010
# Epoch 10/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5995 - loss: 1.0650
# Epoch 10: val_accuracy did not improve from 0.63380
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.5995 - loss: 1.0650 - val_accuracy: 0.6323 - val_loss: 0.9932 - learning_rate: 0.0010
# Epoch 11/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6113 - loss: 1.0388
# Epoch 11: val_accuracy improved from 0.63380 to 0.63528, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6113 - loss: 1.0388 - val_accuracy: 0.6353 - val_loss: 0.9648 - learning_rate: 0.0010
# Epoch 12/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6164 - loss: 1.0147
# Epoch 12: val_accuracy did not improve from 0.63528
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 39ms/step - accuracy: 0.6164 - loss: 1.0147 - val_accuracy: 0.6332 - val_loss: 0.9941 - learning_rate: 0.0010
# Epoch 13/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6269 - loss: 1.0016
# Epoch 13: val_accuracy improved from 0.63528 to 0.64914, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6269 - loss: 1.0016 - val_accuracy: 0.6491 - val_loss: 0.9867 - learning_rate: 0.0010
# Epoch 14/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6311 - loss: 0.9857
# Epoch 14: val_accuracy did not improve from 0.64914
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6311 - loss: 0.9857 - val_accuracy: 0.6464 - val_loss: 0.9548 - learning_rate: 0.0010
# Epoch 15/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6289 - loss: 0.9800
# Epoch 15: val_accuracy improved from 0.64914 to 0.65984, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6289 - loss: 0.9799 - val_accuracy: 0.6598 - val_loss: 0.9494 - learning_rate: 0.0010
# Epoch 16/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6390 - loss: 0.9621
# Epoch 16: val_accuracy did not improve from 0.65984
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6390 - loss: 0.9620 - val_accuracy: 0.6469 - val_loss: 0.9439 - learning_rate: 0.0010
# Epoch 17/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6471 - loss: 0.9437
# Epoch 17: val_accuracy improved from 0.65984 to 0.66677, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.6471 - loss: 0.9437 - val_accuracy: 0.6668 - val_loss: 0.9368 - learning_rate: 0.0010
# Epoch 18/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6529 - loss: 0.9279
# Epoch 18: val_accuracy improved from 0.66677 to 0.68112, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6529 - loss: 0.9279 - val_accuracy: 0.6811 - val_loss: 0.8562 - learning_rate: 0.0010
# Epoch 19/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6531 - loss: 0.9125
# Epoch 19: val_accuracy did not improve from 0.68112
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6531 - loss: 0.9125 - val_accuracy: 0.6739 - val_loss: 0.8844 - learning_rate: 0.0010
# Epoch 20/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6629 - loss: 0.8974
# Epoch 20: val_accuracy did not improve from 0.68112
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6629 - loss: 0.8974 - val_accuracy: 0.6790 - val_loss: 0.8647 - learning_rate: 0.0010
# Epoch 21/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6611 - loss: 0.9058
# Epoch 21: val_accuracy improved from 0.68112 to 0.68835, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6611 - loss: 0.9058 - val_accuracy: 0.6883 - val_loss: 0.8501 - learning_rate: 0.0010
# Epoch 22/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6679 - loss: 0.8879
# Epoch 22: val_accuracy did not improve from 0.68835
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6679 - loss: 0.8879 - val_accuracy: 0.6877 - val_loss: 0.8366 - learning_rate: 0.0010
# Epoch 23/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6763 - loss: 0.8749
# Epoch 23: val_accuracy did not improve from 0.68835
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6763 - loss: 0.8749 - val_accuracy: 0.6827 - val_loss: 0.8581 - learning_rate: 0.0010
# Epoch 24/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6714 - loss: 0.8780
# Epoch 24: val_accuracy improved from 0.68835 to 0.69538, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.6714 - loss: 0.8780 - val_accuracy: 0.6954 - val_loss: 0.8286 - learning_rate: 0.0010
# Epoch 25/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6781 - loss: 0.8593
# Epoch 25: val_accuracy did not improve from 0.69538
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6781 - loss: 0.8593 - val_accuracy: 0.6928 - val_loss: 0.8888 - learning_rate: 0.0010
# Epoch 26/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6842 - loss: 0.8483
# Epoch 26: val_accuracy did not improve from 0.69538
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6842 - loss: 0.8483 - val_accuracy: 0.6913 - val_loss: 0.8294 - learning_rate: 0.0010
# Epoch 27/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6810 - loss: 0.8462
# Epoch 27: val_accuracy improved from 0.69538 to 0.69914, saving model to best_emotion_model.keras
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6810 - loss: 0.8462 - val_accuracy: 0.6991 - val_loss: 0.8317 - learning_rate: 0.0010
# Epoch 28/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6940 - loss: 0.8179
# Epoch 28: val_accuracy improved from 0.69914 to 0.71755, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.6940 - loss: 0.8178 - val_accuracy: 0.7176 - val_loss: 0.7887 - learning_rate: 2.0000e-04
# Epoch 29/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7045 - loss: 0.7974
# Epoch 29: val_accuracy did not improve from 0.71755
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7045 - loss: 0.7974 - val_accuracy: 0.7159 - val_loss: 0.7657 - learning_rate: 2.0000e-04
# Epoch 30/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7091 - loss: 0.7831
# Epoch 30: val_accuracy did not improve from 0.71755
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7091 - loss: 0.7831 - val_accuracy: 0.7169 - val_loss: 0.7651 - learning_rate: 2.0000e-04
# Epoch 31/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7139 - loss: 0.7704
# Epoch 31: val_accuracy improved from 0.71755 to 0.71924, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.7139 - loss: 0.7704 - val_accuracy: 0.7192 - val_loss: 0.7638 - learning_rate: 2.0000e-04
# Epoch 32/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7151 - loss: 0.7604
# Epoch 32: val_accuracy improved from 0.71924 to 0.72567, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.7151 - loss: 0.7604 - val_accuracy: 0.7257 - val_loss: 0.7527 - learning_rate: 2.0000e-04
# Epoch 33/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7177 - loss: 0.7496
# Epoch 33: val_accuracy did not improve from 0.72567
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.7177 - loss: 0.7496 - val_accuracy: 0.7236 - val_loss: 0.7630 - learning_rate: 2.0000e-04
# Epoch 34/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7213 - loss: 0.7488
# Epoch 34: val_accuracy did not improve from 0.72567
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7213 - loss: 0.7488 - val_accuracy: 0.7212 - val_loss: 0.7482 - learning_rate: 2.0000e-04
# Epoch 35/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7174 - loss: 0.7481
# Epoch 35: val_accuracy improved from 0.72567 to 0.72894, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.7174 - loss: 0.7481 - val_accuracy: 0.7289 - val_loss: 0.7428 - learning_rate: 2.0000e-04
# Epoch 36/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7226 - loss: 0.7451
# Epoch 36: val_accuracy improved from 0.72894 to 0.72983, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7226 - loss: 0.7451 - val_accuracy: 0.7298 - val_loss: 0.7479 - learning_rate: 2.0000e-04
# Epoch 37/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7297 - loss: 0.7285
# Epoch 37: val_accuracy improved from 0.72983 to 0.73438, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.7297 - loss: 0.7285 - val_accuracy: 0.7344 - val_loss: 0.7278 - learning_rate: 2.0000e-04
# Epoch 38/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7320 - loss: 0.7281
# Epoch 38: val_accuracy improved from 0.73438 to 0.73458, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 51s 40ms/step - accuracy: 0.7320 - loss: 0.7281 - val_accuracy: 0.7346 - val_loss: 0.7206 - learning_rate: 2.0000e-04
# Epoch 39/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7320 - loss: 0.7221
# Epoch 39: val_accuracy did not improve from 0.73458
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7320 - loss: 0.7221 - val_accuracy: 0.7305 - val_loss: 0.7486 - learning_rate: 2.0000e-04
# Epoch 40/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7354 - loss: 0.7163
# Epoch 40: val_accuracy did not improve from 0.73458
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7354 - loss: 0.7163 - val_accuracy: 0.7308 - val_loss: 0.7347 - learning_rate: 2.0000e-04
# Epoch 41/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7376 - loss: 0.7058
# Epoch 41: val_accuracy did not improve from 0.73458
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7376 - loss: 0.7058 - val_accuracy: 0.7321 - val_loss: 0.7368 - learning_rate: 2.0000e-04
# Epoch 42/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7380 - loss: 0.7095
# Epoch 42: val_accuracy improved from 0.73458 to 0.73557, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7380 - loss: 0.7095 - val_accuracy: 0.7356 - val_loss: 0.7248 - learning_rate: 4.0000e-05
# Epoch 43/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7329 - loss: 0.7162
# Epoch 43: val_accuracy improved from 0.73557 to 0.73953, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 50s 40ms/step - accuracy: 0.7329 - loss: 0.7162 - val_accuracy: 0.7395 - val_loss: 0.7210 - learning_rate: 4.0000e-05
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 38.

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 668ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 34s 148ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.52      0.45      0.48      1024
#    disgusted       0.64      0.69      0.66       111
#        angry       0.55      0.62      0.58       958
#      neutral       0.57      0.69      0.62      1233
#          sad       0.60      0.45      0.51      1247
#    surprised       0.71      0.85      0.77       831
#        happy       0.88      0.83      0.86      1774
#
#     accuracy                           0.66      7178
#    macro avg       0.64      0.65      0.64      7178
# weighted avg       0.66      0.66      0.65      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.5606 - loss: 1.2081
# Test Loss: 0.973230242729187, Test Accuracy: 0.6568682193756104

# %%
model.save('CNN-4Block.keras')

# %%
model.save('CNN-4Block.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
