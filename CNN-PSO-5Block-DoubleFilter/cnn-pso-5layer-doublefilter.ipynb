# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-05-18 08:10:35.478950: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779091835.675596      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779091835.730999      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779091836.193964      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779091836.194014      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779091836.194017      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779091836.194020      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'surprised': 7215, 'angry': 7215, 'neutral': 7215, 'happy': 7215, 'disgusted': 7215, 'fearful': 7215, 'sad': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5766, 'disgusted': 5770, 'angry': 5771, 'neutral': 5774, 'sad': 5782, 'surprised': 5766, 'happy': 5775}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # PSO

# %%
pip install pyswarms
# Out:
# Collecting pyswarms
#   Downloading pyswarms-1.3.0-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (2.0.2)
# Requirement already satisfied: matplotlib>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from pyswarms) (3.10.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from pyswarms) (25.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pyswarms) (4.67.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pyswarms) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.3.1->pyswarms) (1.17.0)
# Downloading pyswarms-1.3.0-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: pyswarms
# Successfully installed pyswarms-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyswarms as ps

# %%
import pyswarms as ps
import tensorflow.keras.backend as K
import gc
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

img_height = 48
img_width = 48 

def fitness_function(params):
    results = []
    
    for p in params:
        # Ekstraksi parameter dari partikel PSO (Total 9 Dimensi sekarang)
        lr = p[0]
        f1 = int(p[1])   
        f2 = int(p[2])   
        f3 = int(p[3])   
        f4 = int(p[4])   
        f5 = int(p[5])   
        dense_u = int(p[6]) 
        dropout = p[7] 
        ukuran_filter = int(p[8])
        
        # Build model berdasarkan partikel
        model = models.Sequential([
            layers.Input(shape=(img_height, img_width, 3)),
            
            # Block 1: 48x48 -> Pool (2,2) -> 24x24
            layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f1*2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 2: 24x24 -> Pool (2,2) -> 12x12
            layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 3: 12x12 -> Pool (2,2) -> 6x6
            layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 4: 6x6 -> Pool (2,2) -> 3x3
            layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
            # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
            layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),

            layers.Flatten(),
            layers.Dense(dense_u, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),
            layers.Dense(len(classes), activation='softmax')
        ])
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
        
        # Evaluasi cepat 
        history = model.fit(train_generator, epochs=3, 
                            validation_data=validation_generator, 
                            verbose=0)
        
        val_acc = max(history.history['val_accuracy'])
        results.append(1 - val_acc)
        
        K.clear_session()
        del model
        gc.collect()
        
    return np.array(results)

# %%
# Batas Pencarian: [LR, F1, F2, F3, F4, F5, Dense, Dropout, Ukuran_Filter]
lb = [1e-4, 16, 32, 64, 128, 128, 128, 0.1, 3]   
ub = [1e-2, 64, 128, 256, 512, 512, 1024, 0.4, 5] 

# Jalankan Optimizer dengan dimensions=9
optimizer = ps.single.GlobalBestPSO(n_particles=10, 
                                    dimensions=9, 
                                    options={'c1': 0.5, 'c2': 0.3, 'w': 0.9}, 
                                    bounds=(lb, ub))

best_cost, best_pos = optimizer.optimize(fitness_function, iters=5)
# Out:
# 2026-05-18 08:35:59,756 - pyswarms.single.global_best - INFO - Optimize for 5 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|5/5, best_cost=0.482
# 2026-05-18 11:32:12,570 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.48193246126174927, best pos: [4.45009661e-03 4.90437791e+01 8.34568750e+01 1.74404678e+02
#  2.35139130e+02 1.46923810e+02 3.63293894e+02 1.02083196e-01
#  3.03612563e+00]

# %%
print(f"""
=== Hasil Optimasi PSO ===
Learning Rate : {best_pos[0]:.6f}
Filter 1      : {int(best_pos[1])}
Filter 2      : {int(best_pos[2])}
Filter 3      : {int(best_pos[3])}
Filter 4      : {int(best_pos[4])}
Filter 5      : {int(best_pos[5])}
Dense Units   : {int(best_pos[6])}
Dropout       : {best_pos[7]:.2f}
Ukuran Filter : {int(best_pos[8])}
""")
# Out:
# === Hasil Optimasi PSO ===
# Learning Rate : 0.004450
# Filter 1      : 49
# Filter 2      : 83
# Filter 3      : 174
# Filter 4      : 235
# Filter 5      : 146
# Dense Units   : 363
# Dropout       : 0.10
# Ukuran Filter : 3

# %%
lr_best = best_pos[0]
f1 = int(best_pos[1])
f2 = int(best_pos[2])
f3 = int(best_pos[3])
f4 = int(best_pos[4])
f5 = int(best_pos[5])
dense_u = int(best_pos[6])
dropout = best_pos[7]
ukuran_filter = int(best_pos[8])

# %% [markdown]
# # Modeling

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN-PSO-5Layer-DoubleFilter"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow import keras

# 1. Gunakan nilai hasil PSO langsung ke dalam Adam Optimizer
# Ganti 'lr_best' dengan variabel nilai dari PSO kamu
optimizer_pso = Adam(learning_rate=lr_best) 

# 2. Checkpoint: Cukup simpan model terbaik berdasarkan val_accuracy
checkpoint = ModelCheckpoint(
    'best_model' + model_name + '.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 3. Hapus ReduceLROnPlateau dari daftar callback agar LR tetap FIXED
callbacks_list = [checkpoint]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1: 48x48 -> Pool (2,2) -> 24x24
        layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f1*2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 2: 24x24 -> Pool (2,2) -> 12x12
        layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 3: 12x12 -> Pool (2,2) -> 6x6
        layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 4: 6x6 -> Pool (2,2) -> 3x3
        layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
        # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
        layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),

        layers.Flatten(),
        layers.Dense(dense_u, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),
        layers.Dense(len(classes), activation='softmax')
    ])
    
    return model

# %%
model = build_final_model()
model.compile(optimizer=optimizer_pso, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 49)     │         1,372 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 49)     │           196 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 98)     │        43,316 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 98)     │           392 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 98)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 98)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 83)     │        73,289 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 83)     │           332 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 83)     │        62,084 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 83)     │           332 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 83)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 83)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 174)    │       130,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 12, 12, 174)    │           696 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 174)    │       272,658 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 12, 174)    │           696 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 174)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 174)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 6, 235)      │       368,245 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 6, 235)      │           940 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 6, 6, 235)      │       497,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 6, 6, 235)      │           940 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 235)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 235)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 3, 3, 146)      │       308,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 3, 3, 146)      │           584 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 3, 146)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1314)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 363)            │       477,345 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 363)            │         1,452 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 363)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         2,548 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,243,765 (8.56 MB)
#  Trainable params: 2,240,485 (8.55 MB)
#  Non-trainable params: 3,280 (12.81 KB)

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn_pos_5_Doublefilter.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1890 - loss: 2.1310
# Epoch 1: val_accuracy improved from -inf to 0.28859, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 82s 54ms/step - accuracy: 0.1890 - loss: 2.1309 - val_accuracy: 0.2886 - val_loss: 1.8056
# Epoch 2/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3327 - loss: 1.7104
# Epoch 2: val_accuracy improved from 0.28859 to 0.42857, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.3327 - loss: 1.7103 - val_accuracy: 0.4286 - val_loss: 1.4859
# Epoch 3/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4699 - loss: 1.3985
# Epoch 3: val_accuracy improved from 0.42857 to 0.47975, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.4699 - loss: 1.3985 - val_accuracy: 0.4798 - val_loss: 1.3647
# Epoch 4/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5322 - loss: 1.2468
# Epoch 4: val_accuracy improved from 0.47975 to 0.57380, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.5322 - loss: 1.2468 - val_accuracy: 0.5738 - val_loss: 1.1442
# Epoch 5/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5674 - loss: 1.1525
# Epoch 5: val_accuracy improved from 0.57380 to 0.57638, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5674 - loss: 1.1525 - val_accuracy: 0.5764 - val_loss: 1.1341
# Epoch 6/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5912 - loss: 1.0898
# Epoch 6: val_accuracy improved from 0.57638 to 0.57875, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5912 - loss: 1.0898 - val_accuracy: 0.5788 - val_loss: 1.1124
# Epoch 7/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6099 - loss: 1.0397
# Epoch 7: val_accuracy improved from 0.57875 to 0.61449, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6100 - loss: 1.0397 - val_accuracy: 0.6145 - val_loss: 1.0458
# Epoch 8/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6283 - loss: 0.9951
# Epoch 8: val_accuracy did not improve from 0.61449
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6283 - loss: 0.9951 - val_accuracy: 0.5152 - val_loss: 1.2901
# Epoch 9/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6389 - loss: 0.9673
# Epoch 9: val_accuracy improved from 0.61449 to 0.63914, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6389 - loss: 0.9673 - val_accuracy: 0.6391 - val_loss: 0.9641
# Epoch 10/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6496 - loss: 0.9404
# Epoch 10: val_accuracy improved from 0.63914 to 0.64439, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6496 - loss: 0.9404 - val_accuracy: 0.6444 - val_loss: 0.9495
# Epoch 11/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6597 - loss: 0.9147
# Epoch 11: val_accuracy improved from 0.64439 to 0.65736, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6597 - loss: 0.9147 - val_accuracy: 0.6574 - val_loss: 0.9124
# Epoch 12/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6697 - loss: 0.8854
# Epoch 12: val_accuracy improved from 0.65736 to 0.67528, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6697 - loss: 0.8854 - val_accuracy: 0.6753 - val_loss: 0.8706
# Epoch 13/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6826 - loss: 0.8508
# Epoch 13: val_accuracy did not improve from 0.67528
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6826 - loss: 0.8508 - val_accuracy: 0.6420 - val_loss: 0.9715
# Epoch 14/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6867 - loss: 0.8441
# Epoch 14: val_accuracy did not improve from 0.67528
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6867 - loss: 0.8441 - val_accuracy: 0.6709 - val_loss: 0.8826
# Epoch 15/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6982 - loss: 0.8206
# Epoch 15: val_accuracy improved from 0.67528 to 0.68993, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6982 - loss: 0.8207 - val_accuracy: 0.6899 - val_loss: 0.8443
# Epoch 16/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7001 - loss: 0.8086
# Epoch 16: val_accuracy improved from 0.68993 to 0.69379, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7001 - loss: 0.8086 - val_accuracy: 0.6938 - val_loss: 0.8201
# Epoch 17/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7043 - loss: 0.7993
# Epoch 17: val_accuracy did not improve from 0.69379
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.7043 - loss: 0.7993 - val_accuracy: 0.6897 - val_loss: 0.8317
# Epoch 18/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7149 - loss: 0.7711
# Epoch 18: val_accuracy did not improve from 0.69379
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7149 - loss: 0.7711 - val_accuracy: 0.6821 - val_loss: 0.8453
# Epoch 19/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7152 - loss: 0.7667
# Epoch 19: val_accuracy did not improve from 0.69379
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.7152 - loss: 0.7667 - val_accuracy: 0.6604 - val_loss: 0.9208
# Epoch 20/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7223 - loss: 0.7512
# Epoch 20: val_accuracy improved from 0.69379 to 0.70785, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7223 - loss: 0.7512 - val_accuracy: 0.7079 - val_loss: 0.7827
# Epoch 21/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7248 - loss: 0.7415
# Epoch 21: val_accuracy did not improve from 0.70785
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7248 - loss: 0.7415 - val_accuracy: 0.6600 - val_loss: 0.9228
# Epoch 22/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7331 - loss: 0.7230
# Epoch 22: val_accuracy improved from 0.70785 to 0.70795, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.7331 - loss: 0.7230 - val_accuracy: 0.7079 - val_loss: 0.7890
# Epoch 23/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7368 - loss: 0.7143
# Epoch 23: val_accuracy did not improve from 0.70795
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7368 - loss: 0.7143 - val_accuracy: 0.5594 - val_loss: 1.2579
# Epoch 24/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7341 - loss: 0.7161
# Epoch 24: val_accuracy improved from 0.70795 to 0.71033, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7341 - loss: 0.7161 - val_accuracy: 0.7103 - val_loss: 0.7897
# Epoch 25/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7437 - loss: 0.6983
# Epoch 25: val_accuracy did not improve from 0.71033
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7437 - loss: 0.6983 - val_accuracy: 0.7024 - val_loss: 0.8078
# Epoch 26/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7446 - loss: 0.6867
# Epoch 26: val_accuracy improved from 0.71033 to 0.71943, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7446 - loss: 0.6867 - val_accuracy: 0.7194 - val_loss: 0.7682
# Epoch 27/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7510 - loss: 0.6696
# Epoch 27: val_accuracy did not improve from 0.71943
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7510 - loss: 0.6696 - val_accuracy: 0.7114 - val_loss: 0.7836
# Epoch 28/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7632 - loss: 0.6520
# Epoch 28: val_accuracy improved from 0.71943 to 0.72082, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7632 - loss: 0.6520 - val_accuracy: 0.7208 - val_loss: 0.7645
# Epoch 29/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7605 - loss: 0.6531
# Epoch 29: val_accuracy did not improve from 0.72082
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7605 - loss: 0.6531 - val_accuracy: 0.6437 - val_loss: 0.9792
# Epoch 30/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7558 - loss: 0.6651
# Epoch 30: val_accuracy did not improve from 0.72082
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7558 - loss: 0.6651 - val_accuracy: 0.7183 - val_loss: 0.7679
# Epoch 31/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7648 - loss: 0.6394
# Epoch 31: val_accuracy improved from 0.72082 to 0.73032, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7648 - loss: 0.6394 - val_accuracy: 0.7303 - val_loss: 0.7384
# Epoch 32/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7693 - loss: 0.6229
# Epoch 32: val_accuracy did not improve from 0.73032
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7693 - loss: 0.6229 - val_accuracy: 0.7278 - val_loss: 0.7533
# Epoch 33/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7705 - loss: 0.6210
# Epoch 33: val_accuracy did not improve from 0.73032
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7705 - loss: 0.6210 - val_accuracy: 0.7036 - val_loss: 0.8158
# Epoch 34/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7748 - loss: 0.6143
# Epoch 34: val_accuracy improved from 0.73032 to 0.74300, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7748 - loss: 0.6143 - val_accuracy: 0.7430 - val_loss: 0.7059
# Epoch 35/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7746 - loss: 0.6058
# Epoch 35: val_accuracy did not improve from 0.74300
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7746 - loss: 0.6058 - val_accuracy: 0.7404 - val_loss: 0.7213
# Epoch 36/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7793 - loss: 0.6027
# Epoch 36: val_accuracy did not improve from 0.74300
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7793 - loss: 0.6027 - val_accuracy: 0.7357 - val_loss: 0.7228
# Epoch 37/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7856 - loss: 0.5929
# Epoch 37: val_accuracy did not improve from 0.74300
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7856 - loss: 0.5929 - val_accuracy: 0.6959 - val_loss: 0.8333
# Epoch 38/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7873 - loss: 0.5806
# Epoch 38: val_accuracy improved from 0.74300 to 0.74785, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7873 - loss: 0.5806 - val_accuracy: 0.7478 - val_loss: 0.7254
# Epoch 39/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7880 - loss: 0.5795
# Epoch 39: val_accuracy improved from 0.74785 to 0.74993, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7880 - loss: 0.5795 - val_accuracy: 0.7499 - val_loss: 0.6920
# Epoch 40/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7935 - loss: 0.5662
# Epoch 40: val_accuracy improved from 0.74993 to 0.75428, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.7935 - loss: 0.5662 - val_accuracy: 0.7543 - val_loss: 0.7010
# Epoch 41/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7994 - loss: 0.5582
# Epoch 41: val_accuracy did not improve from 0.75428
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7994 - loss: 0.5582 - val_accuracy: 0.7514 - val_loss: 0.7018
# Epoch 42/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7965 - loss: 0.5604
# Epoch 42: val_accuracy improved from 0.75428 to 0.75745, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7965 - loss: 0.5604 - val_accuracy: 0.7574 - val_loss: 0.6935
# Epoch 43/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8003 - loss: 0.5452
# Epoch 43: val_accuracy did not improve from 0.75745
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 55s 44ms/step - accuracy: 0.8003 - loss: 0.5452 - val_accuracy: 0.7480 - val_loss: 0.7086
# Epoch 44/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8018 - loss: 0.5474
# Epoch 44: val_accuracy did not improve from 0.75745
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 55s 43ms/step - accuracy: 0.8018 - loss: 0.5474 - val_accuracy: 0.7516 - val_loss: 0.7121
# Epoch 45/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8070 - loss: 0.5353
# Epoch 45: val_accuracy did not improve from 0.75745
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.8070 - loss: 0.5353 - val_accuracy: 0.7481 - val_loss: 0.7174
# Epoch 46/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8037 - loss: 0.5392
# Epoch 46: val_accuracy improved from 0.75745 to 0.76032, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.8037 - loss: 0.5392 - val_accuracy: 0.7603 - val_loss: 0.6771
# Epoch 47/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8132 - loss: 0.5228
# Epoch 47: val_accuracy did not improve from 0.76032
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.8132 - loss: 0.5228 - val_accuracy: 0.7537 - val_loss: 0.6953
# Epoch 48/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8073 - loss: 0.5303
# Epoch 48: val_accuracy improved from 0.76032 to 0.76210, saving model to best_modelCNN-PSO-5Layer-DoubleFilter.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.8073 - loss: 0.5303 - val_accuracy: 0.7621 - val_loss: 0.6913
# Epoch 49/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8179 - loss: 0.5112
# Epoch 49: val_accuracy did not improve from 0.76210
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.8179 - loss: 0.5112 - val_accuracy: 0.7397 - val_loss: 0.7452
# Epoch 50/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8150 - loss: 0.5104
# Epoch 50: val_accuracy did not improve from 0.76210
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.8150 - loss: 0.5104 - val_accuracy: 0.7546 - val_loss: 0.6936

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 52s 230ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.56      0.40      0.47      1024
#    disgusted       0.62      0.72      0.66       111
#        angry       0.55      0.64      0.59       958
#      neutral       0.56      0.70      0.62      1233
#          sad       0.54      0.56      0.55      1247
#    surprised       0.78      0.79      0.78       831
#        happy       0.92      0.79      0.85      1774
#
#     accuracy                           0.66      7178
#    macro avg       0.65      0.66      0.65      7178
# weighted avg       0.67      0.66      0.66      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print("Hasil Evaluasi Data Test")
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5559 - loss: 1.3830
# Hasil Evaluasi Data Test
# Test Loss: 1.074601173400879, Test Accuracy: 0.6567289233207703

# %%
# Langsung uji model yang sudah ada
results_train = model.evaluate(train_generator)
print("Hasil Evaluasi Data Latih")
print(f"Train Loss: {results_train[0]}, Train Accuracy: {results_train[1]}")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 45s 36ms/step - accuracy: 0.8369 - loss: 0.4541
# Hasil Evaluasi Data Latih
# Train Loss: 0.45383399724960327, Train Accuracy: 0.8371695876121521

# %%
# Langsung uji model yang sudah ada
results_val = model.evaluate(validation_generator)
print("Hasil Evaluasi Data Validasi")
print(f"Val Loss: {results_val[0]}, Val Accuracy: {results_val[1]}")
# Out:
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.7066 - loss: 0.7997
# Hasil Evaluasi Data Validasi
# Val Loss: 0.6960770487785339, Val Accuracy: 0.757350742816925

# %%
model.save(model_name+'.keras')

# %%
model.save(model_name+'.h5')
# Out:
# 2026-05-18 12:23:05,416 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
checkpoint
