# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-05-13 05:10:42.929824: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778649043.108878      81 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778649043.164236      81 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778649043.569301      81 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778649043.569346      81 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778649043.569349      81 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778649043.569352      81 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'disgusted': 7215, 'sad': 7215, 'surprised': 7215, 'fearful': 7215, 'angry': 7215, 'happy': 7215, 'neutral': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5773, 'disgusted': 5771, 'angry': 5769, 'neutral': 5773, 'sad': 5771, 'surprised': 5774, 'happy': 5773}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # PSO

# %%
pip install pyswarms
# Out:
# Collecting pyswarms
#   Downloading pyswarms-1.3.0-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (2.0.2)
# Requirement already satisfied: matplotlib>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from pyswarms) (3.10.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from pyswarms) (25.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pyswarms) (4.67.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pyswarms) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.3.1->pyswarms) (1.17.0)
# Downloading pyswarms-1.3.0-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.0 MB/s eta 0:00:00
# Installing collected packages: pyswarms
# Successfully installed pyswarms-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyswarms as ps
import tensorflow.keras.backend as K
import gc
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

img_height = 48
img_width = 48 

def fitness_function(params):
    results = []
    
    for p in params:
        # Ekstraksi parameter dari partikel PSO
        lr = p[0]
        f1 = int(p[1])   # Jumlah filter Block 1
        f2 = int(p[2])   # Jumlah filter Block 2
        f3 = int(p[3])   # Jumlah filter Block 3
        f4 = int(p[4])   # Jumlah filter Block 2
        f5 = int(p[5])   # Jumlah filter Block 3
        dense_u = int(p[6]) # Jumlah neuron Dense layer
        dropout = p[7] 
        
        # Build model berdasarkan partikel
        model = models.Sequential([
            layers.Input(shape=(img_height, img_width, 3)),
            
            # Block 1
            layers.Conv2D(f1, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f1*2, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 2
            layers.Conv2D(f2, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 3
            layers.Conv2D(f3, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 4
            layers.Conv2D(f4, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 5
            layers.Conv2D(f4, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            layers.Flatten(),
            layers.Dense(dense_u, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),
            layers.Dense(len(classes), activation='softmax')
        ])
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
        
        # Evaluasi cepat (Fitness function)
        # Gunakan epoch sedikit (misal 3-5) agar pencarian PSO tidak terlalu lama
        history = model.fit(train_generator, epochs=3, 
                            validation_data=validation_generator, 
                            verbose=0)
        
        # Kita ingin memaksimalkan akurasi, jadi perkecil (1 - akurasi)
        val_acc = max(history.history['val_accuracy'])
        results.append(1 - val_acc)
        
        # TAMBAHKAN INI agar memori tidak penuh:
        K.clear_session()
        del model
        gc.collect()
        
    return np.array(results)

# %%
# Batas Pencarian: [LR, F1, F2, F3, Dense]
# Sesuaikan jumlah elemen dengan dimensions=5
lb = [1e-4, 16, 64, 128, 128, 128, 128, 0.1]   # Tambahkan batas bawah untuk F3
ub = [1e-2, 64, 256, 256, 512, 512, 512, 0.4] # Tambahkan batas atas untuk F3

# Jalankan Optimizer
# Pastikan dimensions=5 sesuai dengan jumlah elemen di lb dan ub
optimizer = ps.single.GlobalBestPSO(n_particles=10, 
                                    dimensions=8, 
                                    options={'c1': 0.5, 'c2': 0.3, 'w': 0.9}, 
                                    bounds=(lb, ub))

best_cost, best_pos = optimizer.optimize(fitness_function, iters=5)
# Out:
# 2026-05-13 05:17:57,839 - pyswarms.single.global_best - INFO - Optimize for 5 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best:   0%|          |0/5I0000 00:00:1778649478.729876      81 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778649484.782197     241 service.cc:152] XLA service 0x7d5f54009c80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778649484.782243     241 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1778649485.667310     241 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1778649494.237293     241 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# pyswarms.single.global_best: 100%|██████████|5/5, best_cost=0.452
# 2026-05-13 07:58:44,479 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.4518364667892456, best pos: [5.67348614e-03 3.96774468e+01 1.94241162e+02 2.26466481e+02
#  3.26868917e+02 4.04927709e+02 1.58278861e+02 1.03614617e-01]

# %%
print(f"""
=== Hasil Optimasi PSO ===
Learning Rate : {best_pos[0]:.6f}
Filter 1      : {int(best_pos[1])}
Filter 2      : {int(best_pos[2])}
Filter 3      : {int(best_pos[3])}
Filter 4      : {int(best_pos[4])}
Filter 5      : {int(best_pos[5])}
Dense Units   : {int(best_pos[6])}
Dropout       : {best_pos[7]:.2f}
""")
# Out:
# === Hasil Optimasi PSO ===
# Learning Rate : 0.005673
# Filter 1      : 39
# Filter 2      : 194
# Filter 3      : 226
# Filter 4      : 326
# Filter 5      : 404
# Dense Units   : 158
# Dropout       : 0.10

# %%
lr_best = best_pos[0]
f1 = int(best_pos[1])
f2 = int(best_pos[2])
f3 = int(best_pos[3])
f4 = int(best_pos[4])
f5 = int(best_pos[5])
dense_u = int(best_pos[6])
dropout = best_pos[7]

# %% [markdown]
# # Modeling

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN_POS_5Layer"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow import keras

# 1. Gunakan nilai hasil PSO langsung ke dalam Adam Optimizer
# Ganti 'lr_best' dengan variabel nilai dari PSO kamu
optimizer_pso = Adam(learning_rate=lr_best) 

# 2. Checkpoint: Cukup simpan model terbaik berdasarkan val_accuracy
checkpoint = ModelCheckpoint(
    'best_model' + model_name + '.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 3. Hapus ReduceLROnPlateau dari daftar callback agar LR tetap FIXED
callbacks_list = [checkpoint]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1
        layers.Conv2D(f1, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f1*2, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 2
        layers.Conv2D(f2, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 3
        layers.Conv2D(f3, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 4
        layers.Conv2D(f4, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 5
        layers.Conv2D(f4, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        layers.Flatten(),
        layers.Dense(dense_u, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),
        layers.Dense(len(classes), activation='softmax')
    ])
    
    return model

# %%
model = build_final_model()
model.compile(optimizer=optimizer_pso, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 39)     │         1,092 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 39)     │           156 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 78)     │        27,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 78)     │           312 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 78)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 78)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 194)    │       136,382 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 194)    │           776 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 194)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 194)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 226)    │       394,822 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 226)    │           904 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 226)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 226)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 326)      │       663,410 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 326)      │         1,304 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 326)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 326)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 326)      │       956,810 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 3, 326)      │         1,304 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 1, 1, 326)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1, 1, 326)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 326)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 158)            │        51,666 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 158)            │           632 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 158)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,113 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,238,139 (8.54 MB)
#  Trainable params: 2,235,445 (8.53 MB)
#  Non-trainable params: 2,694 (10.52 KB)

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn_pos_5.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1961 - loss: 2.0354
# Epoch 1: val_accuracy improved from -inf to 0.19087, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 80s 54ms/step - accuracy: 0.1962 - loss: 2.0353 - val_accuracy: 0.1909 - val_loss: 1.9030
# Epoch 2/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3782 - loss: 1.6171
# Epoch 2: val_accuracy improved from 0.19087 to 0.44590, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.3782 - loss: 1.6170 - val_accuracy: 0.4459 - val_loss: 1.4647
# Epoch 3/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4908 - loss: 1.3529
# Epoch 3: val_accuracy improved from 0.44590 to 0.52480, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.4908 - loss: 1.3528 - val_accuracy: 0.5248 - val_loss: 1.2582
# Epoch 4/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5410 - loss: 1.2294
# Epoch 4: val_accuracy improved from 0.52480 to 0.55361, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5410 - loss: 1.2294 - val_accuracy: 0.5536 - val_loss: 1.1814
# Epoch 5/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5613 - loss: 1.1593
# Epoch 5: val_accuracy improved from 0.55361 to 0.58054, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.5613 - loss: 1.1593 - val_accuracy: 0.5805 - val_loss: 1.1089
# Epoch 6/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5806 - loss: 1.1109
# Epoch 6: val_accuracy improved from 0.58054 to 0.58608, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.5806 - loss: 1.1109 - val_accuracy: 0.5861 - val_loss: 1.1010
# Epoch 7/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5980 - loss: 1.0666
# Epoch 7: val_accuracy improved from 0.58608 to 0.59628, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.5980 - loss: 1.0666 - val_accuracy: 0.5963 - val_loss: 1.0586
# Epoch 8/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6192 - loss: 1.0150
# Epoch 8: val_accuracy improved from 0.59628 to 0.63261, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6192 - loss: 1.0150 - val_accuracy: 0.6326 - val_loss: 0.9651
# Epoch 9/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6295 - loss: 0.9965
# Epoch 9: val_accuracy did not improve from 0.63261
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.6295 - loss: 0.9965 - val_accuracy: 0.6218 - val_loss: 1.0161
# Epoch 10/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6379 - loss: 0.9666
# Epoch 10: val_accuracy improved from 0.63261 to 0.63974, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6379 - loss: 0.9666 - val_accuracy: 0.6397 - val_loss: 0.9647
# Epoch 11/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6427 - loss: 0.9538
# Epoch 11: val_accuracy did not improve from 0.63974
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6427 - loss: 0.9538 - val_accuracy: 0.6202 - val_loss: 1.0009
# Epoch 12/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6547 - loss: 0.9202
# Epoch 12: val_accuracy did not improve from 0.63974
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6547 - loss: 0.9202 - val_accuracy: 0.6040 - val_loss: 1.0711
# Epoch 13/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6632 - loss: 0.8979
# Epoch 13: val_accuracy improved from 0.63974 to 0.66716, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6632 - loss: 0.8979 - val_accuracy: 0.6672 - val_loss: 0.8835
# Epoch 14/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6698 - loss: 0.8829
# Epoch 14: val_accuracy did not improve from 0.66716
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6698 - loss: 0.8829 - val_accuracy: 0.6185 - val_loss: 1.0334
# Epoch 15/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6770 - loss: 0.8652
# Epoch 15: val_accuracy did not improve from 0.66716
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6770 - loss: 0.8652 - val_accuracy: 0.6307 - val_loss: 0.9696
# Epoch 16/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6807 - loss: 0.8581
# Epoch 16: val_accuracy improved from 0.66716 to 0.66914, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6807 - loss: 0.8581 - val_accuracy: 0.6691 - val_loss: 0.8849
# Epoch 17/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6912 - loss: 0.8271
# Epoch 17: val_accuracy did not improve from 0.66914
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6912 - loss: 0.8271 - val_accuracy: 0.5915 - val_loss: 1.1331
# Epoch 18/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6929 - loss: 0.8263
# Epoch 18: val_accuracy did not improve from 0.66914
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6929 - loss: 0.8263 - val_accuracy: 0.6363 - val_loss: 0.9773
# Epoch 19/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7014 - loss: 0.8167
# Epoch 19: val_accuracy did not improve from 0.66914
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7014 - loss: 0.8167 - val_accuracy: 0.6610 - val_loss: 0.9222
# Epoch 20/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7066 - loss: 0.7936
# Epoch 20: val_accuracy improved from 0.66914 to 0.68874, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7066 - loss: 0.7936 - val_accuracy: 0.6887 - val_loss: 0.8438
# Epoch 21/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7130 - loss: 0.7802
# Epoch 21: val_accuracy improved from 0.68874 to 0.69548, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7129 - loss: 0.7802 - val_accuracy: 0.6955 - val_loss: 0.8015
# Epoch 22/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7121 - loss: 0.7716
# Epoch 22: val_accuracy did not improve from 0.69548
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7121 - loss: 0.7716 - val_accuracy: 0.6885 - val_loss: 0.8358
# Epoch 23/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7232 - loss: 0.7520
# Epoch 23: val_accuracy improved from 0.69548 to 0.69577, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7232 - loss: 0.7521 - val_accuracy: 0.6958 - val_loss: 0.8145
# Epoch 24/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7160 - loss: 0.7519
# Epoch 24: val_accuracy improved from 0.69577 to 0.70102, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7160 - loss: 0.7519 - val_accuracy: 0.7010 - val_loss: 0.8050
# Epoch 25/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7209 - loss: 0.7510
# Epoch 25: val_accuracy did not improve from 0.70102
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7209 - loss: 0.7510 - val_accuracy: 0.6940 - val_loss: 0.8136
# Epoch 26/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7261 - loss: 0.7475
# Epoch 26: val_accuracy improved from 0.70102 to 0.70854, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7261 - loss: 0.7474 - val_accuracy: 0.7085 - val_loss: 0.7860
# Epoch 27/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7282 - loss: 0.7223
# Epoch 27: val_accuracy improved from 0.70854 to 0.71191, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7282 - loss: 0.7223 - val_accuracy: 0.7119 - val_loss: 0.7802
# Epoch 28/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7364 - loss: 0.7137
# Epoch 28: val_accuracy improved from 0.71191 to 0.71636, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7364 - loss: 0.7137 - val_accuracy: 0.7164 - val_loss: 0.7580
# Epoch 29/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7373 - loss: 0.7002
# Epoch 29: val_accuracy improved from 0.71636 to 0.72577, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7373 - loss: 0.7002 - val_accuracy: 0.7258 - val_loss: 0.7598
# Epoch 30/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7466 - loss: 0.6941
# Epoch 30: val_accuracy did not improve from 0.72577
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7466 - loss: 0.6941 - val_accuracy: 0.7132 - val_loss: 0.7673
# Epoch 31/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7437 - loss: 0.6957
# Epoch 31: val_accuracy improved from 0.72577 to 0.72824, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7437 - loss: 0.6957 - val_accuracy: 0.7282 - val_loss: 0.7492
# Epoch 32/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7481 - loss: 0.6736
# Epoch 32: val_accuracy did not improve from 0.72824
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7481 - loss: 0.6737 - val_accuracy: 0.7243 - val_loss: 0.7647
# Epoch 33/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7517 - loss: 0.6744
# Epoch 33: val_accuracy did not improve from 0.72824
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7517 - loss: 0.6744 - val_accuracy: 0.7272 - val_loss: 0.7449
# Epoch 34/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7526 - loss: 0.6657
# Epoch 34: val_accuracy improved from 0.72824 to 0.73240, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7526 - loss: 0.6657 - val_accuracy: 0.7324 - val_loss: 0.7264
# Epoch 35/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7600 - loss: 0.6560
# Epoch 35: val_accuracy did not improve from 0.73240
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7600 - loss: 0.6560 - val_accuracy: 0.7283 - val_loss: 0.7316
# Epoch 36/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7582 - loss: 0.6551
# Epoch 36: val_accuracy did not improve from 0.73240
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7582 - loss: 0.6551 - val_accuracy: 0.7147 - val_loss: 0.8008
# Epoch 37/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7684 - loss: 0.6345
# Epoch 37: val_accuracy improved from 0.73240 to 0.73379, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7684 - loss: 0.6345 - val_accuracy: 0.7338 - val_loss: 0.7321
# Epoch 38/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7679 - loss: 0.6322
# Epoch 38: val_accuracy improved from 0.73379 to 0.73438, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7679 - loss: 0.6322 - val_accuracy: 0.7344 - val_loss: 0.7085
# Epoch 39/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7736 - loss: 0.6156
# Epoch 39: val_accuracy did not improve from 0.73438
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7736 - loss: 0.6157 - val_accuracy: 0.7275 - val_loss: 0.7394
# Epoch 40/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7738 - loss: 0.6188
# Epoch 40: val_accuracy improved from 0.73438 to 0.74458, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7738 - loss: 0.6188 - val_accuracy: 0.7446 - val_loss: 0.7099
# Epoch 41/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7770 - loss: 0.6125
# Epoch 41: val_accuracy improved from 0.74458 to 0.74814, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7770 - loss: 0.6125 - val_accuracy: 0.7481 - val_loss: 0.6794
# Epoch 42/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7758 - loss: 0.6093
# Epoch 42: val_accuracy did not improve from 0.74814
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7758 - loss: 0.6093 - val_accuracy: 0.7285 - val_loss: 0.7376
# Epoch 43/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7866 - loss: 0.5834
# Epoch 43: val_accuracy did not improve from 0.74814
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.7866 - loss: 0.5834 - val_accuracy: 0.7418 - val_loss: 0.7056
# Epoch 44/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7831 - loss: 0.5920
# Epoch 44: val_accuracy improved from 0.74814 to 0.75101, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7831 - loss: 0.5920 - val_accuracy: 0.7510 - val_loss: 0.6940
# Epoch 45/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7866 - loss: 0.5907
# Epoch 45: val_accuracy improved from 0.75101 to 0.75299, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7866 - loss: 0.5907 - val_accuracy: 0.7530 - val_loss: 0.6774
# Epoch 46/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7889 - loss: 0.5749
# Epoch 46: val_accuracy improved from 0.75299 to 0.75527, saving model to best_modelCNN_POS_5Layer.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7889 - loss: 0.5749 - val_accuracy: 0.7553 - val_loss: 0.6768
# Epoch 47/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7902 - loss: 0.5792
# Epoch 47: val_accuracy did not improve from 0.75527
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7902 - loss: 0.5792 - val_accuracy: 0.7449 - val_loss: 0.7072
# Epoch 48/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7906 - loss: 0.5715
# Epoch 48: val_accuracy did not improve from 0.75527
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7906 - loss: 0.5715 - val_accuracy: 0.7444 - val_loss: 0.7126
# Epoch 49/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7985 - loss: 0.5602
# Epoch 49: val_accuracy did not improve from 0.75527
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7985 - loss: 0.5602 - val_accuracy: 0.7408 - val_loss: 0.7190
# Epoch 50/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7976 - loss: 0.5515
# Epoch 50: val_accuracy did not improve from 0.75527
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7976 - loss: 0.5515 - val_accuracy: 0.7461 - val_loss: 0.7170

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 50s 219ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.57      0.47      0.52      1024
#    disgusted       0.86      0.66      0.74       111
#        angry       0.56      0.63      0.59       958
#      neutral       0.56      0.67      0.61      1233
#          sad       0.54      0.55      0.54      1247
#    surprised       0.78      0.80      0.79       831
#        happy       0.92      0.79      0.85      1774
#
#     accuracy                           0.66      7178
#    macro avg       0.68      0.66      0.67      7178
# weighted avg       0.68      0.66      0.67      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.5748 - loss: 1.3898
# Test Loss: 1.0720323324203491, Test Accuracy: 0.6629980206489563

# %%
model.save(model_name+'.keras')

# %%
model.save(model_name+'.h5')
# Out:
# 2026-05-13 08:50:12,324 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
