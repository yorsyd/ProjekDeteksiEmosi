# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-04-28 07:44:49.023049: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777362289.204092      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777362289.257117      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777362289.688368      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777362289.688406      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777362289.688409      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777362289.688411      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'fearful': 7215, 'happy': 7215, 'surprised': 7215, 'neutral': 7215, 'angry': 7215, 'disgusted': 7215, 'sad': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5766, 'disgusted': 5775, 'angry': 5779, 'neutral': 5775, 'sad': 5769, 'surprised': 5769, 'happy': 5771}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # Modeling

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1
        layers.Conv2D(32, (15, 15), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(64, (15, 15), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 2
        layers.Conv2D(128, (15, 15), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(256, (15, 15), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Full Connected
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(len(classes), activation='softmax') # Mengikuti jumlah class kamu
    ])
    
    return model

model = build_final_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 48, 48, 32)     │        21,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 48, 48, 64)     │       460,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 24, 24, 128)    │     1,843,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 12, 12, 256)    │     7,373,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     4,719,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,425,543 (55.03 MB)
#  Trainable params: 14,423,559 (55.02 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN-LargeFilter"

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# 1. Checkpoint: Simpan model terbaik secara otomatis
checkpoint = ModelCheckpoint(
    'best_emotion_model.keras', # Gunakan ekstensi .keras
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 2. Learning Rate Scheduler: Menurunkan LR jika akurasi stagnan
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=0.00001,
    verbose=1
)

# Define the callback
early_stopping = EarlyStopping(
    monitor='val_loss',      # Metric to monitor
    patience=5,              # Number of epochs with no improvement
    restore_best_weights=True, # Restores model weights from the best epoch
    verbose=1
)

# Gabungkan callbacks
callbacks_list = [checkpoint, lr_scheduler, early_stopping]

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777363141.831959     153 service.cc:152] XLA service 0x7d2a14003bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777363141.832013     153 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1777363142.506351     153 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-28 07:59:08.328106: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.4 = (f32[64,32,15,15]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,32,48,48]{3,2,1,0} %bitcast.16224, f32[32,64,48,48]{3,2,1,0} %bitcast.16288), window={size=15x15 pad=7_7x7_7}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/sequential_1_1/conv2d_5_1/convolution/Conv2DBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-04-28 07:59:08.589336: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.261408844s
# Trying algorithm eng0{} for conv %cudnn-conv-bw-filter.4 = (f32[64,32,15,15]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,32,48,48]{3,2,1,0} %bitcast.16224, f32[32,64,48,48]{3,2,1,0} %bitcast.16288), window={size=15x15 pad=7_7x7_7}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", metadata={op_type="Conv2DBackpropFilter" op_name="gradient_tape/sequential_1_1/conv2d_5_1/convolution/Conv2DBackpropFilter" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#    5/1263 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - accuracy: 0.1026 - loss: 3.7226
# I0000 00:00:1777363153.521728     153 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.1718 - loss: 2.4216
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_accuracy improved from -inf to 0.20087, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 89s 59ms/step - accuracy: 0.1718 - loss: 2.4214 - val_accuracy: 0.2009 - val_loss: 1.9895 - learning_rate: 0.0010
# Epoch 2/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2549 - loss: 1.9068
# Epoch 2: val_accuracy improved from 0.20087 to 0.25453, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.2549 - loss: 1.9068 - val_accuracy: 0.2545 - val_loss: 1.8769 - learning_rate: 0.0010
# Epoch 3/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.3198 - loss: 1.7569
# Epoch 3: val_accuracy improved from 0.25453 to 0.38006, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.3198 - loss: 1.7569 - val_accuracy: 0.3801 - val_loss: 1.6249 - learning_rate: 0.0010
# Epoch 4/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3755 - loss: 1.6182
# Epoch 4: val_accuracy did not improve from 0.38006
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.3756 - loss: 1.6181 - val_accuracy: 0.3686 - val_loss: 1.6498 - learning_rate: 0.0010
# Epoch 5/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4226 - loss: 1.5185
# Epoch 5: val_accuracy improved from 0.38006 to 0.44095, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.4226 - loss: 1.5184 - val_accuracy: 0.4409 - val_loss: 1.4720 - learning_rate: 0.0010
# Epoch 6/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4544 - loss: 1.4357
# Epoch 6: val_accuracy improved from 0.44095 to 0.47332, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.4544 - loss: 1.4357 - val_accuracy: 0.4733 - val_loss: 1.4101 - learning_rate: 0.0010
# Epoch 7/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.4858 - loss: 1.3591
# Epoch 7: val_accuracy improved from 0.47332 to 0.51391, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.4858 - loss: 1.3591 - val_accuracy: 0.5139 - val_loss: 1.2771 - learning_rate: 0.0010
# Epoch 8/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5145 - loss: 1.2789
# Epoch 8: val_accuracy did not improve from 0.51391
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.5145 - loss: 1.2789 - val_accuracy: 0.5135 - val_loss: 1.2910 - learning_rate: 0.0010
# Epoch 9/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5386 - loss: 1.2292
# Epoch 9: val_accuracy improved from 0.51391 to 0.52529, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.5386 - loss: 1.2292 - val_accuracy: 0.5253 - val_loss: 1.2591 - learning_rate: 0.0010
# Epoch 10/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5436 - loss: 1.2088
# Epoch 10: val_accuracy improved from 0.52529 to 0.56232, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.5436 - loss: 1.2088 - val_accuracy: 0.5623 - val_loss: 1.1462 - learning_rate: 0.0010
# Epoch 11/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5555 - loss: 1.1772
# Epoch 11: val_accuracy improved from 0.56232 to 0.58133, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.5555 - loss: 1.1772 - val_accuracy: 0.5813 - val_loss: 1.1010 - learning_rate: 0.0010
# Epoch 12/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5782 - loss: 1.1104
# Epoch 12: val_accuracy improved from 0.58133 to 0.58836, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.5782 - loss: 1.1104 - val_accuracy: 0.5884 - val_loss: 1.0904 - learning_rate: 0.0010
# Epoch 13/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5900 - loss: 1.0904
# Epoch 13: val_accuracy improved from 0.58836 to 0.59945, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.5900 - loss: 1.0904 - val_accuracy: 0.5994 - val_loss: 1.0530 - learning_rate: 0.0010
# Epoch 14/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6031 - loss: 1.0581
# Epoch 14: val_accuracy improved from 0.59945 to 0.60479, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.6031 - loss: 1.0581 - val_accuracy: 0.6048 - val_loss: 1.0385 - learning_rate: 0.0010
# Epoch 15/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6007 - loss: 1.0622
# Epoch 15: val_accuracy improved from 0.60479 to 0.61202, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.6007 - loss: 1.0622 - val_accuracy: 0.6120 - val_loss: 1.0411 - learning_rate: 0.0010
# Epoch 16/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6176 - loss: 1.0218
# Epoch 16: val_accuracy improved from 0.61202 to 0.62608, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.6176 - loss: 1.0218 - val_accuracy: 0.6261 - val_loss: 0.9866 - learning_rate: 0.0010
# Epoch 17/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6285 - loss: 0.9828
# Epoch 17: val_accuracy improved from 0.62608 to 0.63499, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6285 - loss: 0.9828 - val_accuracy: 0.6350 - val_loss: 0.9571 - learning_rate: 0.0010
# Epoch 18/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6392 - loss: 0.9639
# Epoch 18: val_accuracy did not improve from 0.63499
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6392 - loss: 0.9639 - val_accuracy: 0.6026 - val_loss: 1.0403 - learning_rate: 0.0010
# Epoch 19/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6416 - loss: 0.9628
# Epoch 19: val_accuracy improved from 0.63499 to 0.64548, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.6416 - loss: 0.9628 - val_accuracy: 0.6455 - val_loss: 0.9431 - learning_rate: 0.0010
# Epoch 20/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6509 - loss: 0.9305
# Epoch 20: val_accuracy did not improve from 0.64548
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6509 - loss: 0.9305 - val_accuracy: 0.6402 - val_loss: 0.9491 - learning_rate: 0.0010
# Epoch 21/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6596 - loss: 0.9066
# Epoch 21: val_accuracy did not improve from 0.64548
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6596 - loss: 0.9066 - val_accuracy: 0.6317 - val_loss: 1.0031 - learning_rate: 0.0010
# Epoch 22/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6581 - loss: 0.9073
# Epoch 22: val_accuracy improved from 0.64548 to 0.65538, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.6581 - loss: 0.9073 - val_accuracy: 0.6554 - val_loss: 0.9213 - learning_rate: 0.0010
# Epoch 23/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6698 - loss: 0.8906
# Epoch 23: val_accuracy improved from 0.65538 to 0.66053, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.6698 - loss: 0.8906 - val_accuracy: 0.6605 - val_loss: 0.8894 - learning_rate: 0.0010
# Epoch 24/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6762 - loss: 0.8721
# Epoch 24: val_accuracy improved from 0.66053 to 0.67290, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.6762 - loss: 0.8721 - val_accuracy: 0.6729 - val_loss: 0.8745 - learning_rate: 0.0010
# Epoch 25/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6837 - loss: 0.8482
# Epoch 25: val_accuracy did not improve from 0.67290
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.6837 - loss: 0.8482 - val_accuracy: 0.6700 - val_loss: 0.8873 - learning_rate: 0.0010
# Epoch 26/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6957 - loss: 0.8321
# Epoch 26: val_accuracy did not improve from 0.67290
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6957 - loss: 0.8321 - val_accuracy: 0.6700 - val_loss: 0.8795 - learning_rate: 0.0010
# Epoch 27/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6972 - loss: 0.8146
# Epoch 27: val_accuracy improved from 0.67290 to 0.68449, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.6972 - loss: 0.8146 - val_accuracy: 0.6845 - val_loss: 0.8561 - learning_rate: 0.0010
# Epoch 28/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7109 - loss: 0.7915
# Epoch 28: val_accuracy did not improve from 0.68449
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7109 - loss: 0.7916 - val_accuracy: 0.6772 - val_loss: 0.8776 - learning_rate: 0.0010
# Epoch 29/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7085 - loss: 0.7883
# Epoch 29: val_accuracy did not improve from 0.68449
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7085 - loss: 0.7883 - val_accuracy: 0.6805 - val_loss: 0.8552 - learning_rate: 0.0010
# Epoch 30/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7193 - loss: 0.7631
# Epoch 30: val_accuracy did not improve from 0.68449
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7193 - loss: 0.7631 - val_accuracy: 0.6831 - val_loss: 0.8527 - learning_rate: 0.0010
# Epoch 31/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7187 - loss: 0.7691
# Epoch 31: val_accuracy improved from 0.68449 to 0.70300, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7187 - loss: 0.7691 - val_accuracy: 0.7030 - val_loss: 0.8125 - learning_rate: 0.0010
# Epoch 32/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7266 - loss: 0.7375
# Epoch 32: val_accuracy did not improve from 0.70300
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.7266 - loss: 0.7375 - val_accuracy: 0.7017 - val_loss: 0.8134 - learning_rate: 0.0010
# Epoch 33/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7263 - loss: 0.7477
# Epoch 33: val_accuracy improved from 0.70300 to 0.70379, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 49ms/step - accuracy: 0.7263 - loss: 0.7477 - val_accuracy: 0.7038 - val_loss: 0.8130 - learning_rate: 0.0010
# Epoch 34/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7324 - loss: 0.7282
# Epoch 34: val_accuracy did not improve from 0.70379
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.7324 - loss: 0.7282 - val_accuracy: 0.6985 - val_loss: 0.8123 - learning_rate: 0.0010
# Epoch 35/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7401 - loss: 0.7143
# Epoch 35: val_accuracy improved from 0.70379 to 0.71072, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7401 - loss: 0.7143 - val_accuracy: 0.7107 - val_loss: 0.7836 - learning_rate: 0.0010
# Epoch 36/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7429 - loss: 0.7066
# Epoch 36: val_accuracy did not improve from 0.71072
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7429 - loss: 0.7066 - val_accuracy: 0.7008 - val_loss: 0.8113 - learning_rate: 0.0010
# Epoch 37/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7453 - loss: 0.6921
# Epoch 37: val_accuracy did not improve from 0.71072
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7453 - loss: 0.6921 - val_accuracy: 0.7102 - val_loss: 0.7921 - learning_rate: 0.0010
# Epoch 38/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7578 - loss: 0.6662
# Epoch 38: val_accuracy improved from 0.71072 to 0.71874, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.7578 - loss: 0.6662 - val_accuracy: 0.7187 - val_loss: 0.7654 - learning_rate: 0.0010
# Epoch 39/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7560 - loss: 0.6656
# Epoch 39: val_accuracy did not improve from 0.71874
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7560 - loss: 0.6656 - val_accuracy: 0.7166 - val_loss: 0.7885 - learning_rate: 0.0010
# Epoch 40/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7622 - loss: 0.6537
# Epoch 40: val_accuracy did not improve from 0.71874
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7622 - loss: 0.6537 - val_accuracy: 0.7168 - val_loss: 0.7752 - learning_rate: 0.0010
# Epoch 41/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7674 - loss: 0.6469
# Epoch 41: val_accuracy improved from 0.71874 to 0.72329, saving model to best_emotion_model.keras
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7674 - loss: 0.6469 - val_accuracy: 0.7233 - val_loss: 0.7665 - learning_rate: 0.0010
# Epoch 42/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7774 - loss: 0.6174
# Epoch 42: val_accuracy improved from 0.72329 to 0.74032, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7775 - loss: 0.6173 - val_accuracy: 0.7403 - val_loss: 0.7168 - learning_rate: 2.0000e-04
# Epoch 43/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7921 - loss: 0.5773
# Epoch 43: val_accuracy improved from 0.74032 to 0.75319, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7921 - loss: 0.5773 - val_accuracy: 0.7532 - val_loss: 0.6988 - learning_rate: 2.0000e-04
# Epoch 44/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7973 - loss: 0.5640
# Epoch 44: val_accuracy did not improve from 0.75319
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7973 - loss: 0.5640 - val_accuracy: 0.7443 - val_loss: 0.7126 - learning_rate: 2.0000e-04
# Epoch 45/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7980 - loss: 0.5524
# Epoch 45: val_accuracy improved from 0.75319 to 0.75943, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.7980 - loss: 0.5524 - val_accuracy: 0.7594 - val_loss: 0.6958 - learning_rate: 2.0000e-04
# Epoch 46/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8023 - loss: 0.5439
# Epoch 46: val_accuracy did not improve from 0.75943
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.8023 - loss: 0.5439 - val_accuracy: 0.7533 - val_loss: 0.6947 - learning_rate: 2.0000e-04
# Epoch 47/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8049 - loss: 0.5433
# Epoch 47: val_accuracy did not improve from 0.75943
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.8049 - loss: 0.5433 - val_accuracy: 0.7571 - val_loss: 0.6965 - learning_rate: 2.0000e-04
# Epoch 48/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8108 - loss: 0.5250
# Epoch 48: val_accuracy did not improve from 0.75943
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.8108 - loss: 0.5250 - val_accuracy: 0.7576 - val_loss: 0.6883 - learning_rate: 2.0000e-04
# Epoch 49/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8114 - loss: 0.5222
# Epoch 49: val_accuracy improved from 0.75943 to 0.75983, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.8114 - loss: 0.5222 - val_accuracy: 0.7598 - val_loss: 0.6846 - learning_rate: 2.0000e-04
# Epoch 50/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8134 - loss: 0.5153
# Epoch 50: val_accuracy improved from 0.75983 to 0.76032, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.8134 - loss: 0.5153 - val_accuracy: 0.7603 - val_loss: 0.6834 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 50.

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 776ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 51s 224ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.55      0.47      0.51      1024
#    disgusted       0.79      0.69      0.74       111
#        angry       0.54      0.62      0.58       958
#      neutral       0.57      0.60      0.58      1233
#          sad       0.51      0.50      0.51      1247
#    surprised       0.75      0.83      0.79       831
#        happy       0.86      0.80      0.83      1774
#
#     accuracy                           0.65      7178
#    macro avg       0.65      0.65      0.65      7178
# weighted avg       0.65      0.65      0.65      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step - accuracy: 0.5563 - loss: 1.4526
# Test Loss: 1.129059076309204, Test Accuracy: 0.646140992641449

# %%
model.save('CNN-LargeFilter.keras')

# %%
model.save('CNN-LargeFilter.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
