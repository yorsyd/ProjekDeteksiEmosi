# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'fearful': 7215, 'neutral': 7215, 'surprised': 7215, 'happy': 7215, 'disgusted': 7215, 'sad': 7215, 'angry': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5768, 'disgusted': 5771, 'angry': 5776, 'neutral': 5770, 'sad': 5771, 'surprised': 5773, 'happy': 5775}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # PSO

# %%
pip install pyswarms
# Out:
# Collecting pyswarms
#   Downloading pyswarms-1.3.0-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (2.0.2)
# Requirement already satisfied: matplotlib>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from pyswarms) (3.10.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from pyswarms) (25.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pyswarms) (4.67.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pyswarms) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.3.1->pyswarms) (1.17.0)
# Downloading pyswarms-1.3.0-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: pyswarms
# Successfully installed pyswarms-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyswarms as ps
import tensorflow.keras.backend as K
import gc
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

img_height = 48
img_width = 48 

def fitness_function(params):
    results = []
    
    for p in params:
        # Ekstraksi parameter dari partikel PSO
        lr = p[0]
        f1 = int(p[1])   # Jumlah filter Block 1
        f2 = int(p[2])   # Jumlah filter Block 2
        f3 = int(p[3])   # Jumlah filter Block 3
        dense_u = int(p[4]) # Jumlah neuron Dense layer
        
        # Build model berdasarkan partikel
        model = models.Sequential([
            layers.Input(shape=(img_height, img_width, 3)),
            
            # Block 1
            layers.Conv2D(f1, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f1*2, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),

            # Block 2
            layers.Conv2D(f2, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),

            # Block 3
            layers.Conv2D(f3, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),

            layers.Flatten(),
            layers.Dense(dense_u, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.5),
            layers.Dense(len(classes), activation='softmax')
        ])
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
        
        # Evaluasi cepat (Fitness function)
        # Gunakan epoch sedikit (misal 3-5) agar pencarian PSO tidak terlalu lama
        history = model.fit(train_generator, epochs=5, 
                            validation_data=validation_generator, 
                            verbose=0)
        
        # Kita ingin memaksimalkan akurasi, jadi perkecil (1 - akurasi)
        val_acc = max(history.history['val_accuracy'])
        results.append(1 - val_acc)
        
        # TAMBAHKAN INI agar memori tidak penuh:
        K.clear_session()
        del model
        gc.collect()
        
    return np.array(results)

# %%
# Batas Pencarian: [LR, F1, F2, F3, Dense]
# Sesuaikan jumlah elemen dengan dimensions=5
lb = [1e-4, 16, 64, 128, 128]   # Tambahkan batas bawah untuk F3
ub = [1e-2, 64, 256, 512, 1024] # Tambahkan batas atas untuk F3

# Jalankan Optimizer
# Pastikan dimensions=5 sesuai dengan jumlah elemen di lb dan ub
optimizer = ps.single.GlobalBestPSO(n_particles=10, 
                                    dimensions=5, 
                                    options={'c1': 0.5, 'c2': 0.3, 'w': 0.9}, 
                                    bounds=(lb, ub))

best_cost, best_pos = optimizer.optimize(fitness_function, iters=1)
# Out:
# 2026-05-11 23:50:07,848 - pyswarms.single.global_best - INFO - Optimize for 1 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best:   0%|          |0/1I0000 00:00:1778543408.767323      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778543414.166754     169 service.cc:152] XLA service 0x7f0b40017dc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778543414.166811     169 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1778543414.869427     169 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1778543421.284801     169 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# pyswarms.single.global_best: 100%|██████████|1/1, best_cost=0.483
# 2026-05-12 00:39:26,544 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.4825264811515808, best pos: [6.39678426e-03 2.73340336e+01 2.44137080e+02 2.46444094e+02
#  2.18151948e+02]

# %%
print(f"""
=== Hasil Optimasi PSO ===
Learning Rate : {best_pos[0]:.6f}
Filter 1      : {int(best_pos[1])}
Filter 2      : {int(best_pos[2])}
Filter 3      : {int(best_pos[3])}
Dense Units   : {int(best_pos[4])}
""")
# Out:
# === Hasil Optimasi PSO ===
# Learning Rate : 0.006397
# Filter 1      : 27
# Filter 2      : 244
# Filter 3      : 246
# Dense Units   : 218

# %% [markdown]
# # Modeling

# %%
f1 = int(best_pos[1])
f2 = int(best_pos[2])
f3 = int(best_pos[3])
dense_u = int(best_pos[4])

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1
        layers.Conv2D(f1, (3, 3), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(f1*2, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 2
        layers.Conv2D(f2, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(f3, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Full Connected
        layers.Flatten(),
        layers.Dense(dense_u, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(len(classes), activation='softmax') # Mengikuti jumlah class kamu
    ])
    
    return model

model = build_final_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 27)     │           756 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 27)     │           108 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 54)     │        13,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 54)     │           216 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 54)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 54)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 244)    │       118,828 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 244)    │           976 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 244)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 244)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 246)    │       540,462 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 246)    │           984 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 246)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 246)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8856)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 218)            │     1,930,826 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 218)            │           872 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 218)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         1,533 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,608,737 (9.95 MB)
#  Trainable params: 2,607,159 (9.95 MB)
#  Non-trainable params: 1,578 (6.16 KB)

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN_POS_5"

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn_pos_5.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# 1. Checkpoint: Simpan model terbaik secara otomatis
checkpoint = ModelCheckpoint(
    'best_emotion_model.keras', # Gunakan ekstensi .keras
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 2. Learning Rate Scheduler: Menurunkan LR jika akurasi stagnan
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=0.00001
)

# Gabungkan callbacks
callbacks_list = [checkpoint, lr_scheduler]

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2255 - loss: 2.1880
# Epoch 1: val_accuracy improved from -inf to 0.31759, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 75s 53ms/step - accuracy: 0.2256 - loss: 2.1876 - val_accuracy: 0.3176 - val_loss: 2.4833 - learning_rate: 0.0010
# Epoch 2/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3956 - loss: 1.5852
# Epoch 2: val_accuracy improved from 0.31759 to 0.39432, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.3956 - loss: 1.5852 - val_accuracy: 0.3943 - val_loss: 1.7169 - learning_rate: 0.0010
# Epoch 3/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4374 - loss: 1.4819
# Epoch 3: val_accuracy improved from 0.39432 to 0.47134, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.4375 - loss: 1.4818 - val_accuracy: 0.4713 - val_loss: 1.3946 - learning_rate: 0.0010
# Epoch 4/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4897 - loss: 1.3484
# Epoch 4: val_accuracy improved from 0.47134 to 0.53807, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.4897 - loss: 1.3483 - val_accuracy: 0.5381 - val_loss: 1.2277 - learning_rate: 0.0010
# Epoch 5/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5125 - loss: 1.3018
# Epoch 5: val_accuracy did not improve from 0.53807
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.5125 - loss: 1.3018 - val_accuracy: 0.3841 - val_loss: 1.6292 - learning_rate: 0.0010
# Epoch 6/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5247 - loss: 1.2670
# Epoch 6: val_accuracy did not improve from 0.53807
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5247 - loss: 1.2670 - val_accuracy: 0.4852 - val_loss: 1.3564 - learning_rate: 0.0010
# Epoch 7/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5331 - loss: 1.2424
# Epoch 7: val_accuracy improved from 0.53807 to 0.57311, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.5331 - loss: 1.2423 - val_accuracy: 0.5731 - val_loss: 1.1404 - learning_rate: 0.0010
# Epoch 8/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5558 - loss: 1.1904
# Epoch 8: val_accuracy improved from 0.57311 to 0.57479, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.5558 - loss: 1.1904 - val_accuracy: 0.5748 - val_loss: 1.1429 - learning_rate: 0.0010
# Epoch 9/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5679 - loss: 1.1630
# Epoch 9: val_accuracy did not improve from 0.57479
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.5679 - loss: 1.1630 - val_accuracy: 0.5278 - val_loss: 1.2600 - learning_rate: 0.0010
# Epoch 10/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5720 - loss: 1.1454
# Epoch 10: val_accuracy improved from 0.57479 to 0.61489, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.5720 - loss: 1.1454 - val_accuracy: 0.6149 - val_loss: 1.0338 - learning_rate: 0.0010
# Epoch 11/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5768 - loss: 1.1288
# Epoch 11: val_accuracy improved from 0.61489 to 0.62717, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.5768 - loss: 1.1288 - val_accuracy: 0.6272 - val_loss: 0.9934 - learning_rate: 0.0010
# Epoch 12/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5889 - loss: 1.0956
# Epoch 12: val_accuracy did not improve from 0.62717
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.5889 - loss: 1.0956 - val_accuracy: 0.6148 - val_loss: 1.0151 - learning_rate: 0.0010
# Epoch 13/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5966 - loss: 1.0844
# Epoch 13: val_accuracy improved from 0.62717 to 0.64043, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5966 - loss: 1.0844 - val_accuracy: 0.6404 - val_loss: 0.9603 - learning_rate: 0.0010
# Epoch 14/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5976 - loss: 1.0771
# Epoch 14: val_accuracy improved from 0.64043 to 0.64330, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.5976 - loss: 1.0771 - val_accuracy: 0.6433 - val_loss: 0.9474 - learning_rate: 0.0010
# Epoch 15/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6108 - loss: 1.0426
# Epoch 15: val_accuracy did not improve from 0.64330
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 46ms/step - accuracy: 0.6108 - loss: 1.0426 - val_accuracy: 0.6389 - val_loss: 0.9632 - learning_rate: 0.0010
# Epoch 16/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6154 - loss: 1.0337
# Epoch 16: val_accuracy did not improve from 0.64330
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6154 - loss: 1.0337 - val_accuracy: 0.6381 - val_loss: 0.9468 - learning_rate: 0.0010
# Epoch 17/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6119 - loss: 1.0336
# Epoch 17: val_accuracy did not improve from 0.64330
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6119 - loss: 1.0336 - val_accuracy: 0.6388 - val_loss: 0.9441 - learning_rate: 0.0010
# Epoch 18/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6194 - loss: 1.0225
# Epoch 18: val_accuracy improved from 0.64330 to 0.65568, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6194 - loss: 1.0225 - val_accuracy: 0.6557 - val_loss: 0.9092 - learning_rate: 0.0010
# Epoch 19/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6219 - loss: 1.0091
# Epoch 19: val_accuracy did not improve from 0.65568
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.6219 - loss: 1.0091 - val_accuracy: 0.6432 - val_loss: 0.9371 - learning_rate: 0.0010
# Epoch 20/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6245 - loss: 1.0046
# Epoch 20: val_accuracy did not improve from 0.65568
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6245 - loss: 1.0046 - val_accuracy: 0.6457 - val_loss: 0.9299 - learning_rate: 0.0010
# Epoch 21/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6322 - loss: 0.9867
# Epoch 21: val_accuracy did not improve from 0.65568
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.6322 - loss: 0.9867 - val_accuracy: 0.6493 - val_loss: 0.9253 - learning_rate: 0.0010
# Epoch 22/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6358 - loss: 0.9721
# Epoch 22: val_accuracy improved from 0.65568 to 0.67855, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6359 - loss: 0.9721 - val_accuracy: 0.6785 - val_loss: 0.8546 - learning_rate: 2.0000e-04
# Epoch 23/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6476 - loss: 0.9416
# Epoch 23: val_accuracy improved from 0.67855 to 0.68488, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6476 - loss: 0.9416 - val_accuracy: 0.6849 - val_loss: 0.8378 - learning_rate: 2.0000e-04
# Epoch 24/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6528 - loss: 0.9295
# Epoch 24: val_accuracy did not improve from 0.68488
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6528 - loss: 0.9295 - val_accuracy: 0.6778 - val_loss: 0.8465 - learning_rate: 2.0000e-04
# Epoch 25/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6531 - loss: 0.9212
# Epoch 25: val_accuracy did not improve from 0.68488
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6531 - loss: 0.9212 - val_accuracy: 0.6832 - val_loss: 0.8378 - learning_rate: 2.0000e-04
# Epoch 26/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6598 - loss: 0.9102
# Epoch 26: val_accuracy improved from 0.68488 to 0.68637, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6598 - loss: 0.9102 - val_accuracy: 0.6864 - val_loss: 0.8317 - learning_rate: 2.0000e-04
# Epoch 27/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6629 - loss: 0.8997
# Epoch 27: val_accuracy improved from 0.68637 to 0.68746, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6629 - loss: 0.8997 - val_accuracy: 0.6875 - val_loss: 0.8340 - learning_rate: 2.0000e-04
# Epoch 28/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6646 - loss: 0.8966
# Epoch 28: val_accuracy did not improve from 0.68746
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6646 - loss: 0.8966 - val_accuracy: 0.6833 - val_loss: 0.8361 - learning_rate: 2.0000e-04
# Epoch 29/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6644 - loss: 0.9008
# Epoch 29: val_accuracy improved from 0.68746 to 0.68884, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6644 - loss: 0.9008 - val_accuracy: 0.6888 - val_loss: 0.8223 - learning_rate: 2.0000e-04
# Epoch 30/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6664 - loss: 0.8911
# Epoch 30: val_accuracy improved from 0.68884 to 0.69062, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6664 - loss: 0.8911 - val_accuracy: 0.6906 - val_loss: 0.8185 - learning_rate: 2.0000e-04
# Epoch 31/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6679 - loss: 0.8917
# Epoch 31: val_accuracy did not improve from 0.69062
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6679 - loss: 0.8917 - val_accuracy: 0.6895 - val_loss: 0.8160 - learning_rate: 2.0000e-04
# Epoch 32/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6674 - loss: 0.8872
# Epoch 32: val_accuracy improved from 0.69062 to 0.69142, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.6674 - loss: 0.8872 - val_accuracy: 0.6914 - val_loss: 0.8195 - learning_rate: 2.0000e-04
# Epoch 33/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6703 - loss: 0.8828
# Epoch 33: val_accuracy did not improve from 0.69142
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6703 - loss: 0.8828 - val_accuracy: 0.6897 - val_loss: 0.8168 - learning_rate: 2.0000e-04
# Epoch 34/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6749 - loss: 0.8761
# Epoch 34: val_accuracy did not improve from 0.69142
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6749 - loss: 0.8762 - val_accuracy: 0.6882 - val_loss: 0.8120 - learning_rate: 2.0000e-04
# Epoch 35/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6695 - loss: 0.8765
# Epoch 35: val_accuracy improved from 0.69142 to 0.70013, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6695 - loss: 0.8765 - val_accuracy: 0.7001 - val_loss: 0.8078 - learning_rate: 2.0000e-04
# Epoch 36/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6734 - loss: 0.8787
# Epoch 36: val_accuracy did not improve from 0.70013
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6734 - loss: 0.8787 - val_accuracy: 0.6976 - val_loss: 0.8062 - learning_rate: 2.0000e-04
# Epoch 37/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6726 - loss: 0.8732
# Epoch 37: val_accuracy did not improve from 0.70013
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6726 - loss: 0.8732 - val_accuracy: 0.6956 - val_loss: 0.8047 - learning_rate: 2.0000e-04
# Epoch 38/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6737 - loss: 0.8674
# Epoch 38: val_accuracy did not improve from 0.70013
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6737 - loss: 0.8674 - val_accuracy: 0.6980 - val_loss: 0.7926 - learning_rate: 2.0000e-04
# Epoch 39/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6831 - loss: 0.8578
# Epoch 39: val_accuracy did not improve from 0.70013
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6831 - loss: 0.8578 - val_accuracy: 0.6963 - val_loss: 0.7996 - learning_rate: 2.0000e-04
# Epoch 40/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6745 - loss: 0.8636
# Epoch 40: val_accuracy did not improve from 0.70013
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.6745 - loss: 0.8636 - val_accuracy: 0.6994 - val_loss: 0.7979 - learning_rate: 2.0000e-04
# Epoch 41/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6819 - loss: 0.8546
# Epoch 41: val_accuracy improved from 0.70013 to 0.70132, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.6819 - loss: 0.8546 - val_accuracy: 0.7013 - val_loss: 0.7885 - learning_rate: 2.0000e-04
# Epoch 42/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6809 - loss: 0.8619
# Epoch 42: val_accuracy improved from 0.70132 to 0.70330, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.6809 - loss: 0.8619 - val_accuracy: 0.7033 - val_loss: 0.7881 - learning_rate: 2.0000e-04
# Epoch 43/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6845 - loss: 0.8473
# Epoch 43: val_accuracy did not improve from 0.70330
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.6845 - loss: 0.8473 - val_accuracy: 0.6977 - val_loss: 0.7985 - learning_rate: 2.0000e-04
# Epoch 44/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6842 - loss: 0.8482
# Epoch 44: val_accuracy improved from 0.70330 to 0.70953, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6842 - loss: 0.8482 - val_accuracy: 0.7095 - val_loss: 0.7826 - learning_rate: 2.0000e-04
# Epoch 45/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6817 - loss: 0.8491
# Epoch 45: val_accuracy did not improve from 0.70953
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6817 - loss: 0.8491 - val_accuracy: 0.7032 - val_loss: 0.7850 - learning_rate: 2.0000e-04
# Epoch 46/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6887 - loss: 0.8421
# Epoch 46: val_accuracy did not improve from 0.70953
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6887 - loss: 0.8421 - val_accuracy: 0.7055 - val_loss: 0.7893 - learning_rate: 2.0000e-04
# Epoch 47/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6829 - loss: 0.8547
# Epoch 47: val_accuracy did not improve from 0.70953
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.6829 - loss: 0.8547 - val_accuracy: 0.7053 - val_loss: 0.7790 - learning_rate: 2.0000e-04
# Epoch 48/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6856 - loss: 0.8426
# Epoch 48: val_accuracy improved from 0.70953 to 0.71132, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6856 - loss: 0.8426 - val_accuracy: 0.7113 - val_loss: 0.7744 - learning_rate: 2.0000e-04
# Epoch 49/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6947 - loss: 0.8248
# Epoch 49: val_accuracy did not improve from 0.71132
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6947 - loss: 0.8248 - val_accuracy: 0.7058 - val_loss: 0.7780 - learning_rate: 2.0000e-04
# Epoch 50/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6918 - loss: 0.8346
# Epoch 50: val_accuracy did not improve from 0.71132
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6918 - loss: 0.8346 - val_accuracy: 0.7096 - val_loss: 0.7723 - learning_rate: 2.0000e-04

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 31s 136ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.59      0.34      0.43      1024
#    disgusted       0.64      0.75      0.69       111
#        angry       0.58      0.61      0.59       958
#      neutral       0.54      0.71      0.61      1233
#          sad       0.54      0.51      0.53      1247
#    surprised       0.71      0.86      0.78       831
#        happy       0.90      0.83      0.86      1774
#
#     accuracy                           0.66      7178
#    macro avg       0.64      0.66      0.64      7178
# weighted avg       0.66      0.66      0.65      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5226 - loss: 1.2572
# Test Loss: 0.9510869979858398, Test Accuracy: 0.6570075154304504

# %%
model.save('CNN-POS-5.keras')

# %%
model.save('CNN-POS-5.h5')
# Out:
# 2026-05-12 01:32:06,638 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
