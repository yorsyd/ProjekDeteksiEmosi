# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-05-19 07:49:22.459788: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779176962.638435      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779176962.694532      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779176963.111049      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779176963.111090      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779176963.111093      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779176963.111096      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'neutral': 7215, 'happy': 7215, 'sad': 7215, 'disgusted': 7215, 'fearful': 7215, 'surprised': 7215, 'angry': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5774, 'disgusted': 5772, 'angry': 5774, 'neutral': 5770, 'sad': 5771, 'surprised': 5773, 'happy': 5770}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # PSO

# %%
pip install pyswarms
# Out:
# Collecting pyswarms
#   Downloading pyswarms-1.3.0-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (2.0.2)
# Requirement already satisfied: matplotlib>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from pyswarms) (3.10.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from pyswarms) (25.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pyswarms) (4.67.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pyswarms) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.3.1->pyswarms) (1.17.0)
# Downloading pyswarms-1.3.0-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: pyswarms
# Successfully installed pyswarms-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyswarms as ps
import tensorflow.keras.backend as K
import gc
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

img_height = 48
img_width = 48 

def fitness_function(params):
    results = []
    
    for p in params:
        # Ekstraksi parameter dari partikel PSO (Total 9 Dimensi sekarang)
        lr = p[0]
        f1 = int(p[1])   
        f2 = int(p[2])   
        f3 = int(p[3])   
        f4 = int(p[4])   
        f5 = int(p[5])   
        dense_u = int(p[6]) 
        dropout = p[7] 
        ukuran_filter = int(p[8])
        
        # Build model berdasarkan partikel
        model = models.Sequential([
            layers.Input(shape=(img_height, img_width, 3)),
            
            # Block 1: 48x48 -> Pool (2,2) -> 24x24
            layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f1*2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 2: 24x24 -> Pool (2,2) -> 12x12
            layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 3: 12x12 -> Pool (2,2) -> 6x6
            layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 4: 6x6 -> Pool (2,2) -> 3x3
            layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
            # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
            layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),

            layers.Flatten(),
            layers.Dense(dense_u, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),
            layers.Dense(len(classes), activation='softmax')
        ])
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
        
        # Evaluasi cepat 
        history = model.fit(train_generator, epochs=3, 
                            validation_data=validation_generator, 
                            verbose=0)
        
        val_acc = max(history.history['val_accuracy'])
        results.append(1 - val_acc)
        
        K.clear_session()
        del model
        gc.collect()
        
    return np.array(results)

# %%
# Batas Pencarian: [LR, F1, F2, F3, F4, F5, Dense, Dropout, Ukuran_Filter]
lb = [1e-4, 16, 32, 64, 128, 128, 256, 0.1, 3]   
ub = [1e-2, 64, 128, 256, 256, 512, 512, 0.3, 5] 

# Jalankan Optimizer dengan dimensions=9
optimizer = ps.single.GlobalBestPSO(n_particles=10, 
                                    dimensions=9, 
                                    options={'c1': 1.496, 'c2': 1.496, 'w': 0.7298}, 
                                    bounds=(lb, ub))

best_cost, best_pos = optimizer.optimize(fitness_function, iters=10)
# Out:
# 2026-05-19 07:55:32,191 - pyswarms.single.global_best - INFO - Optimize for 10 iters with {'c1': 1.496, 'c2': 1.496, 'w': 0.7298}
# pyswarms.single.global_best:   0%|          |0/10I0000 00:00:1779177333.092481      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779177339.216588     160 service.cc:152] XLA service 0x790b38001c70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779177339.216641     160 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1779177340.137787     160 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1779177347.575973     160 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# pyswarms.single.global_best: 100%|██████████|10/10, best_cost=0.455
# 2026-05-19 13:14:26,477 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.45520246028900146, best pos: [3.30357406e-03 5.03552350e+01 7.09306155e+01 2.11874125e+02
#  2.01273510e+02 4.80206133e+02 3.52605306e+02 1.64674164e-01
#  3.63582661e+00]

# %%
print(f"""
=== Hasil Optimasi PSO ===
Learning Rate : {best_pos[0]:.6f}
Filter 1      : {int(best_pos[1])}
Filter 2      : {int(best_pos[2])}
Filter 3      : {int(best_pos[3])}
Filter 4      : {int(best_pos[4])}
Filter 5      : {int(best_pos[5])}
Dense Units   : {int(best_pos[6])}
Dropout       : {best_pos[7]:.2f}
Ukuran Filter : {int(best_pos[8])}
""")
# Out:
# === Hasil Optimasi PSO ===
# Learning Rate : 0.003304
# Filter 1      : 50
# Filter 2      : 70
# Filter 3      : 211
# Filter 4      : 201
# Filter 5      : 480
# Dense Units   : 352
# Dropout       : 0.16
# Ukuran Filter : 3

# %%
lr_best = best_pos[0]
f1 = int(best_pos[1])
f2 = int(best_pos[2])
f3 = int(best_pos[3])
f4 = int(best_pos[4])
f5 = int(best_pos[5])
dense_u = int(best_pos[6])
dropout = best_pos[7]
ukuran_filter = int(best_pos[8])

# %% [markdown]
# # Modeling

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "cnn-pso10iter-5layer-confFilterV2"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow import keras

# 1. Gunakan nilai hasil PSO langsung ke dalam Adam Optimizer
# Ganti 'lr_best' dengan variabel nilai dari PSO kamu
optimizer_pso = Adam(learning_rate=lr_best) 

# 2. Checkpoint: Cukup simpan model terbaik berdasarkan val_accuracy
checkpoint = ModelCheckpoint(
    'best_model' + model_name + '.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 3. Hapus ReduceLROnPlateau dari daftar callback agar LR tetap FIXED
callbacks_list = [checkpoint]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1: 48x48 -> Pool (2,2) -> 24x24
        layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f1*2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 2: 24x24 -> Pool (2,2) -> 12x12
        layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 3: 12x12 -> Pool (2,2) -> 6x6
        layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 4: 6x6 -> Pool (2,2) -> 3x3
        layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
        # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
        layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),

        layers.Flatten(),
        layers.Dense(dense_u, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),
        layers.Dense(len(classes), activation='softmax')
    ])
    
    return model

# %%
model = build_final_model()
model.compile(optimizer=optimizer_pso, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 50)     │         1,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 50)     │           200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 100)    │        45,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 100)    │           400 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 100)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 100)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 70)     │        63,070 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 70)     │           280 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 70)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 70)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 211)    │       133,141 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 211)    │           844 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 211)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 211)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 201)      │       381,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 201)      │           804 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 201)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 201)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 480)      │       868,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 3, 480)      │         1,920 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 3, 480)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4320)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 352)            │     1,520,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 352)            │         1,408 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 352)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         2,471 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,022,730 (11.53 MB)
#  Trainable params: 3,019,802 (11.52 MB)
#  Non-trainable params: 2,928 (11.44 KB)

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn-pso10iter-5layer-confFilter.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.2107 - loss: 2.1300
# Epoch 1: val_accuracy improved from -inf to 0.18790, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 72s 49ms/step - accuracy: 0.2108 - loss: 2.1296 - val_accuracy: 0.1879 - val_loss: 2.0836
# Epoch 2/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3953 - loss: 1.5817
# Epoch 2: val_accuracy improved from 0.18790 to 0.45025, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.3954 - loss: 1.5815 - val_accuracy: 0.4503 - val_loss: 1.4526
# Epoch 3/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4868 - loss: 1.3578
# Epoch 3: val_accuracy improved from 0.45025 to 0.47055, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.4868 - loss: 1.3578 - val_accuracy: 0.4705 - val_loss: 1.3845
# Epoch 4/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5316 - loss: 1.2554
# Epoch 4: val_accuracy improved from 0.47055 to 0.49530, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.5316 - loss: 1.2554 - val_accuracy: 0.4953 - val_loss: 1.3711
# Epoch 5/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5512 - loss: 1.1993
# Epoch 5: val_accuracy improved from 0.49530 to 0.57856, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.5512 - loss: 1.1993 - val_accuracy: 0.5786 - val_loss: 1.1237
# Epoch 6/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5716 - loss: 1.1315
# Epoch 6: val_accuracy did not improve from 0.57856
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.5716 - loss: 1.1315 - val_accuracy: 0.5743 - val_loss: 1.2736
# Epoch 7/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5855 - loss: 1.1071
# Epoch 7: val_accuracy improved from 0.57856 to 0.61677, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 54s 42ms/step - accuracy: 0.5855 - loss: 1.1071 - val_accuracy: 0.6168 - val_loss: 1.0184
# Epoch 8/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5986 - loss: 1.0664
# Epoch 8: val_accuracy did not improve from 0.61677
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.5986 - loss: 1.0664 - val_accuracy: 0.5859 - val_loss: 1.0931
# Epoch 9/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6074 - loss: 1.0332
# Epoch 9: val_accuracy did not improve from 0.61677
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6074 - loss: 1.0332 - val_accuracy: 0.4319 - val_loss: 1.5925
# Epoch 10/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6082 - loss: 1.0396
# Epoch 10: val_accuracy improved from 0.61677 to 0.62717, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6082 - loss: 1.0396 - val_accuracy: 0.6272 - val_loss: 0.9820
# Epoch 11/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6230 - loss: 0.9912
# Epoch 11: val_accuracy improved from 0.62717 to 0.65003, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6230 - loss: 0.9912 - val_accuracy: 0.6500 - val_loss: 0.9272
# Epoch 12/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6389 - loss: 0.9745
# Epoch 12: val_accuracy improved from 0.65003 to 0.65528, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6389 - loss: 0.9745 - val_accuracy: 0.6553 - val_loss: 0.9200
# Epoch 13/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6424 - loss: 0.9546
# Epoch 13: val_accuracy did not improve from 0.65528
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6424 - loss: 0.9547 - val_accuracy: 0.6495 - val_loss: 0.9129
# Epoch 14/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6498 - loss: 0.9346
# Epoch 14: val_accuracy did not improve from 0.65528
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 54s 42ms/step - accuracy: 0.6498 - loss: 0.9346 - val_accuracy: 0.6200 - val_loss: 1.0113
# Epoch 15/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6507 - loss: 0.9227
# Epoch 15: val_accuracy improved from 0.65528 to 0.67023, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6507 - loss: 0.9227 - val_accuracy: 0.6702 - val_loss: 0.8785
# Epoch 16/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6604 - loss: 0.8990
# Epoch 16: val_accuracy did not improve from 0.67023
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6604 - loss: 0.8990 - val_accuracy: 0.6489 - val_loss: 0.9464
# Epoch 17/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6658 - loss: 0.8871
# Epoch 17: val_accuracy did not improve from 0.67023
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6658 - loss: 0.8872 - val_accuracy: 0.6479 - val_loss: 0.9311
# Epoch 18/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6722 - loss: 0.8716
# Epoch 18: val_accuracy improved from 0.67023 to 0.68211, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 54s 42ms/step - accuracy: 0.6722 - loss: 0.8717 - val_accuracy: 0.6821 - val_loss: 0.8419
# Epoch 19/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6811 - loss: 0.8599
# Epoch 19: val_accuracy improved from 0.68211 to 0.68657, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6811 - loss: 0.8599 - val_accuracy: 0.6866 - val_loss: 0.8362
# Epoch 20/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6811 - loss: 0.8499
# Epoch 20: val_accuracy improved from 0.68657 to 0.70082, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6811 - loss: 0.8499 - val_accuracy: 0.7008 - val_loss: 0.7952
# Epoch 21/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6749 - loss: 0.8763
# Epoch 21: val_accuracy did not improve from 0.70082
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 54s 42ms/step - accuracy: 0.6749 - loss: 0.8763 - val_accuracy: 0.6930 - val_loss: 0.8209
# Epoch 22/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6903 - loss: 0.8305
# Epoch 22: val_accuracy did not improve from 0.70082
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6903 - loss: 0.8306 - val_accuracy: 0.6897 - val_loss: 0.8277
# Epoch 23/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6901 - loss: 0.8248
# Epoch 23: val_accuracy did not improve from 0.70082
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6901 - loss: 0.8248 - val_accuracy: 0.6938 - val_loss: 0.8276
# Epoch 24/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6968 - loss: 0.8190
# Epoch 24: val_accuracy did not improve from 0.70082
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6968 - loss: 0.8190 - val_accuracy: 0.6993 - val_loss: 0.8030
# Epoch 25/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6913 - loss: 0.8194
# Epoch 25: val_accuracy improved from 0.70082 to 0.70478, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6913 - loss: 0.8194 - val_accuracy: 0.7048 - val_loss: 0.7950
# Epoch 26/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7023 - loss: 0.7941
# Epoch 26: val_accuracy did not improve from 0.70478
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7023 - loss: 0.7941 - val_accuracy: 0.6811 - val_loss: 0.8480
# Epoch 27/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.6971 - loss: 0.8010
# Epoch 27: val_accuracy did not improve from 0.70478
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.6971 - loss: 0.8010 - val_accuracy: 0.7004 - val_loss: 0.7978
# Epoch 28/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7063 - loss: 0.7839
# Epoch 28: val_accuracy did not improve from 0.70478
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7063 - loss: 0.7839 - val_accuracy: 0.7027 - val_loss: 0.7966
# Epoch 29/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7054 - loss: 0.7854
# Epoch 29: val_accuracy did not improve from 0.70478
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7054 - loss: 0.7854 - val_accuracy: 0.7027 - val_loss: 0.8003
# Epoch 30/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7149 - loss: 0.7623
# Epoch 30: val_accuracy improved from 0.70478 to 0.71963, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7149 - loss: 0.7623 - val_accuracy: 0.7196 - val_loss: 0.7471
# Epoch 31/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7167 - loss: 0.7584
# Epoch 31: val_accuracy did not improve from 0.71963
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7167 - loss: 0.7584 - val_accuracy: 0.7012 - val_loss: 0.8111
# Epoch 32/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7162 - loss: 0.7635
# Epoch 32: val_accuracy improved from 0.71963 to 0.72003, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7162 - loss: 0.7635 - val_accuracy: 0.7200 - val_loss: 0.7553
# Epoch 33/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7225 - loss: 0.7438
# Epoch 33: val_accuracy did not improve from 0.72003
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7225 - loss: 0.7438 - val_accuracy: 0.7077 - val_loss: 0.7761
# Epoch 34/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7222 - loss: 0.7442
# Epoch 34: val_accuracy did not improve from 0.72003
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7222 - loss: 0.7442 - val_accuracy: 0.7169 - val_loss: 0.7597
# Epoch 35/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7246 - loss: 0.7349
# Epoch 35: val_accuracy did not improve from 0.72003
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7246 - loss: 0.7349 - val_accuracy: 0.7164 - val_loss: 0.7613
# Epoch 36/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7289 - loss: 0.7264
# Epoch 36: val_accuracy improved from 0.72003 to 0.72716, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7289 - loss: 0.7264 - val_accuracy: 0.7272 - val_loss: 0.7436
# Epoch 37/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7291 - loss: 0.7231
# Epoch 37: val_accuracy did not improve from 0.72716
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7291 - loss: 0.7231 - val_accuracy: 0.7272 - val_loss: 0.7419
# Epoch 38/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7318 - loss: 0.7158
# Epoch 38: val_accuracy did not improve from 0.72716
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7318 - loss: 0.7158 - val_accuracy: 0.7212 - val_loss: 0.7465
# Epoch 39/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7362 - loss: 0.7099
# Epoch 39: val_accuracy improved from 0.72716 to 0.73240, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7362 - loss: 0.7099 - val_accuracy: 0.7324 - val_loss: 0.7304
# Epoch 40/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7358 - loss: 0.7067
# Epoch 40: val_accuracy did not improve from 0.73240
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7358 - loss: 0.7067 - val_accuracy: 0.7200 - val_loss: 0.7634
# Epoch 41/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7460 - loss: 0.6929
# Epoch 41: val_accuracy did not improve from 0.73240
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7460 - loss: 0.6929 - val_accuracy: 0.7310 - val_loss: 0.7226
# Epoch 42/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7432 - loss: 0.6842
# Epoch 42: val_accuracy did not improve from 0.73240
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 54s 43ms/step - accuracy: 0.7432 - loss: 0.6842 - val_accuracy: 0.7301 - val_loss: 0.7330
# Epoch 43/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7448 - loss: 0.6827
# Epoch 43: val_accuracy improved from 0.73240 to 0.74230, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7448 - loss: 0.6827 - val_accuracy: 0.7423 - val_loss: 0.6984
# Epoch 44/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7460 - loss: 0.6800
# Epoch 44: val_accuracy did not improve from 0.74230
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7460 - loss: 0.6800 - val_accuracy: 0.7342 - val_loss: 0.7272
# Epoch 45/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7543 - loss: 0.6645
# Epoch 45: val_accuracy improved from 0.74230 to 0.74755, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7543 - loss: 0.6645 - val_accuracy: 0.7475 - val_loss: 0.6884
# Epoch 46/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7482 - loss: 0.6712
# Epoch 46: val_accuracy did not improve from 0.74755
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 52s 42ms/step - accuracy: 0.7482 - loss: 0.6712 - val_accuracy: 0.7277 - val_loss: 0.7402
# Epoch 47/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7502 - loss: 0.6701
# Epoch 47: val_accuracy did not improve from 0.74755
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7502 - loss: 0.6701 - val_accuracy: 0.7435 - val_loss: 0.6884
# Epoch 48/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7532 - loss: 0.6629
# Epoch 48: val_accuracy did not improve from 0.74755
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7532 - loss: 0.6629 - val_accuracy: 0.7440 - val_loss: 0.6976
# Epoch 49/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7578 - loss: 0.6633
# Epoch 49: val_accuracy improved from 0.74755 to 0.75032, saving model to best_modelcnn-pso10iter-5layer-confFilterV2.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7578 - loss: 0.6633 - val_accuracy: 0.7503 - val_loss: 0.6823
# Epoch 50/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.7571 - loss: 0.6507
# Epoch 50: val_accuracy did not improve from 0.75032
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 53s 42ms/step - accuracy: 0.7571 - loss: 0.6508 - val_accuracy: 0.7475 - val_loss: 0.6805

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 53s 234ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.52      0.48      0.50      1024
#    disgusted       0.84      0.67      0.74       111
#        angry       0.56      0.61      0.58       958
#      neutral       0.56      0.69      0.62      1233
#          sad       0.57      0.50      0.54      1247
#    surprised       0.80      0.80      0.80       831
#        happy       0.90      0.83      0.86      1774
#
#     accuracy                           0.66      7178
#    macro avg       0.68      0.65      0.66      7178
# weighted avg       0.67      0.66      0.66      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print("Hasil Evaluasi Data Test")
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 8s 33ms/step - accuracy: 0.5760 - loss: 1.2204
# Hasil Evaluasi Data Test
# Test Loss: 0.9904759526252747, Test Accuracy: 0.6635553240776062

# %%
# Langsung uji model yang sudah ada
results_train = model.evaluate(train_generator)
print("Hasil Evaluasi Data Latih")
print(f"Train Loss: {results_train[0]}, Train Accuracy: {results_train[1]}")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 43s 34ms/step - accuracy: 0.8290 - loss: 0.4771
# Hasil Evaluasi Data Latih
# Train Loss: 0.4695543348789215, Train Accuracy: 0.8312543034553528

# %%
# Langsung uji model yang sudah ada
results_val = model.evaluate(validation_generator)
print("Hasil Evaluasi Data Validasi")
print(f"Val Loss: {results_val[0]}, Val Accuracy: {results_val[1]}")
# Out:
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.7186 - loss: 0.7150
# Hasil Evaluasi Data Validasi
# Val Loss: 0.6771907210350037, Val Accuracy: 0.7506187558174133

# %%
model.save(model_name+'.keras')

# %%
model.save(model_name+'.h5')
# Out:
# 2026-05-19 14:00:55,780 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
checkpoint
