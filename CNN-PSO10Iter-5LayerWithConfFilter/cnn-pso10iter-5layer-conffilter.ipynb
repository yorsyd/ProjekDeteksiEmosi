# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-05-19 00:55:39.301552: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779152139.493265      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779152139.549743      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779152139.997473      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779152139.997531      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779152139.997534      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779152139.997536      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'disgusted': 7215, 'happy': 7215, 'angry': 7215, 'sad': 7215, 'surprised': 7215, 'fearful': 7215, 'neutral': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5769, 'disgusted': 5773, 'angry': 5773, 'neutral': 5773, 'sad': 5775, 'surprised': 5768, 'happy': 5773}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # PSO

# %%
pip install pyswarms
# Out:
# Collecting pyswarms
#   Downloading pyswarms-1.3.0-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (2.0.2)
# Requirement already satisfied: matplotlib>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from pyswarms) (3.10.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from pyswarms) (25.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pyswarms) (4.67.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pyswarms) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.3.1->pyswarms) (1.17.0)
# Downloading pyswarms-1.3.0-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 2.4 MB/s eta 0:00:0000:01
# Installing collected packages: pyswarms
# Successfully installed pyswarms-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyswarms as ps
import tensorflow.keras.backend as K
import gc
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np

img_height = 48
img_width = 48 

def fitness_function(params):
    results = []
    
    for p in params:
        # Ekstraksi parameter dari partikel PSO (Total 9 Dimensi sekarang)
        lr = p[0]
        f1 = int(p[1])   
        f2 = int(p[2])   
        f3 = int(p[3])   
        f4 = int(p[4])   
        f5 = int(p[5])   
        dense_u = int(p[6]) 
        dropout = p[7] 
        ukuran_filter = int(p[8])
        
        # Build model berdasarkan partikel
        model = models.Sequential([
            layers.Input(shape=(img_height, img_width, 3)),
            
            # Block 1: 48x48 -> Pool (2,2) -> 24x24
            layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 2: 24x24 -> Pool (2,2) -> 12x12
            layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 3: 12x12 -> Pool (2,2) -> 6x6
            layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 4: 6x6 -> Pool (2,2) -> 3x3
            layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
            # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
            layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),

            layers.Flatten(),
            layers.Dense(dense_u, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),
            layers.Dense(len(classes), activation='softmax')
        ])
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
        
        # Evaluasi cepat 
        history = model.fit(train_generator, epochs=3, 
                            validation_data=validation_generator, 
                            verbose=0)
        
        val_acc = max(history.history['val_accuracy'])
        results.append(1 - val_acc)
        
        K.clear_session()
        del model
        gc.collect()
        
    return np.array(results)

# %%
# Batas Pencarian: [LR, F1, F2, F3, F4, F5, Dense, Dropout, Ukuran_Filter]
lb = [1e-4, 16, 32, 64, 128, 128, 256, 0.1, 3]   
ub = [1e-2, 64, 128, 256, 256, 512, 1024, 0.3, 5] 

# Jalankan Optimizer dengan dimensions=9
optimizer = ps.single.GlobalBestPSO(n_particles=10, 
                                    dimensions=9, 
                                    options={'c1': 1.496, 'c2': 1.496, 'w': 0.7298}, 
                                    bounds=(lb, ub))

best_cost, best_pos = optimizer.optimize(fitness_function, iters=10)
# Out:
# 2026-05-19 01:02:46,021 - pyswarms.single.global_best - INFO - Optimize for 10 iters with {'c1': 1.496, 'c2': 1.496, 'w': 0.7298}
# pyswarms.single.global_best:   0%|          |0/10I0000 00:00:1779152566.977167      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779152573.504363     171 service.cc:152] XLA service 0x79eac80098c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779152573.504406     171 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1779152574.437298     171 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1779152582.738796     171 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# pyswarms.single.global_best: 100%|██████████|10/10, best_cost=0.454
# 2026-05-19 06:29:39,866 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.45351946353912354, best pos: [1.42238882e-03 5.64471042e+01 1.05977536e+02 1.82100525e+02
#  2.43219688e+02 2.45951457e+02 4.36707382e+02 1.14336281e-01
#  4.58780783e+00]

# %%
print(f"""
=== Hasil Optimasi PSO ===
Learning Rate : {best_pos[0]:.6f}
Filter 1      : {int(best_pos[1])}
Filter 2      : {int(best_pos[2])}
Filter 3      : {int(best_pos[3])}
Filter 4      : {int(best_pos[4])}
Filter 5      : {int(best_pos[5])}
Dense Units   : {int(best_pos[6])}
Dropout       : {best_pos[7]:.2f}
Ukuran Filter : {int(best_pos[8])}
""")
# Out:
# === Hasil Optimasi PSO ===
# Learning Rate : 0.001422
# Filter 1      : 56
# Filter 2      : 105
# Filter 3      : 182
# Filter 4      : 243
# Filter 5      : 245
# Dense Units   : 436
# Dropout       : 0.11
# Ukuran Filter : 4

# %%
lr_best = best_pos[0]
f1 = int(best_pos[1])
f2 = int(best_pos[2])
f3 = int(best_pos[3])
f4 = int(best_pos[4])
f5 = int(best_pos[5])
dense_u = int(best_pos[6])
dropout = best_pos[7]
ukuran_filter = int(best_pos[8])

# %% [markdown]
# # Modeling

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN-PSO-5Layer-Filter-Pooling"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow import keras

# 1. Gunakan nilai hasil PSO langsung ke dalam Adam Optimizer
# Ganti 'lr_best' dengan variabel nilai dari PSO kamu
optimizer_pso = Adam(learning_rate=lr_best) 

# 2. Checkpoint: Cukup simpan model terbaik berdasarkan val_accuracy
checkpoint = ModelCheckpoint(
    'best_model' + model_name + '.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 3. Hapus ReduceLROnPlateau dari daftar callback agar LR tetap FIXED
callbacks_list = [checkpoint]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1: 48x48 -> Pool (2,2) -> 24x24
        layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f1*2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 2: 24x24 -> Pool (2,2) -> 12x12
        layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 3: 12x12 -> Pool (2,2) -> 6x6
        layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 4: 6x6 -> Pool (2,2) -> 3x3
        layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
        # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
        layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),

        layers.Flatten(),
        layers.Dense(dense_u, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),
        layers.Dense(len(classes), activation='softmax')
    ])
    
    return model

# %%
model = build_final_model()
model.compile(optimizer=optimizer_pso, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 56)     │         2,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 56)     │           224 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 112)    │       100,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 112)    │           448 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 112)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 112)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 105)    │       188,265 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 105)    │           420 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 105)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 105)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 182)    │       305,942 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 182)    │           728 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 182)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 182)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 243)      │       707,859 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 243)      │           972 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 243)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 243)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 245)      │       952,805 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 3, 245)      │           980 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 3, 245)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2205)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 436)            │       961,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 436)            │         1,744 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 436)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         3,059 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,228,470 (12.32 MB)
#  Trainable params: 3,225,712 (12.31 MB)
#  Non-trainable params: 2,758 (10.77 KB)

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn-pso10iter-5layer-confFilter.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.2291 - loss: 2.0598
# Epoch 1: val_accuracy improved from -inf to 0.28175, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 82s 55ms/step - accuracy: 0.2292 - loss: 2.0596 - val_accuracy: 0.2818 - val_loss: 1.9539
# Epoch 2/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.4289 - loss: 1.5040
# Epoch 2: val_accuracy did not improve from 0.28175
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.4290 - loss: 1.5039 - val_accuracy: 0.2660 - val_loss: 1.8420
# Epoch 3/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5045 - loss: 1.3229
# Epoch 3: val_accuracy improved from 0.28175 to 0.53618, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5045 - loss: 1.3228 - val_accuracy: 0.5362 - val_loss: 1.2415
# Epoch 4/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5482 - loss: 1.2024
# Epoch 4: val_accuracy improved from 0.53618 to 0.55044, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.5482 - loss: 1.2024 - val_accuracy: 0.5504 - val_loss: 1.1920
# Epoch 5/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5794 - loss: 1.1153
# Epoch 5: val_accuracy improved from 0.55044 to 0.57202, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.5794 - loss: 1.1153 - val_accuracy: 0.5720 - val_loss: 1.1294
# Epoch 6/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5969 - loss: 1.0691
# Epoch 6: val_accuracy improved from 0.57202 to 0.61202, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.5970 - loss: 1.0691 - val_accuracy: 0.6120 - val_loss: 1.0420
# Epoch 7/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6200 - loss: 1.0173
# Epoch 7: val_accuracy did not improve from 0.61202
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6200 - loss: 1.0173 - val_accuracy: 0.5951 - val_loss: 1.0703
# Epoch 8/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6290 - loss: 0.9804
# Epoch 8: val_accuracy improved from 0.61202 to 0.63479, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6290 - loss: 0.9804 - val_accuracy: 0.6348 - val_loss: 0.9682
# Epoch 9/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6365 - loss: 0.9677
# Epoch 9: val_accuracy improved from 0.63479 to 0.64400, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6365 - loss: 0.9677 - val_accuracy: 0.6440 - val_loss: 0.9406
# Epoch 10/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6603 - loss: 0.9197
# Epoch 10: val_accuracy improved from 0.64400 to 0.65390, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6603 - loss: 0.9197 - val_accuracy: 0.6539 - val_loss: 0.9138
# Epoch 11/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6579 - loss: 0.9136
# Epoch 11: val_accuracy improved from 0.65390 to 0.67379, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.6579 - loss: 0.9136 - val_accuracy: 0.6738 - val_loss: 0.8779
# Epoch 12/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6718 - loss: 0.8720
# Epoch 12: val_accuracy improved from 0.67379 to 0.67954, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.6718 - loss: 0.8720 - val_accuracy: 0.6795 - val_loss: 0.8600
# Epoch 13/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6737 - loss: 0.8641
# Epoch 13: val_accuracy did not improve from 0.67954
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6737 - loss: 0.8640 - val_accuracy: 0.6735 - val_loss: 0.8646
# Epoch 14/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6799 - loss: 0.8425
# Epoch 14: val_accuracy improved from 0.67954 to 0.68152, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.6799 - loss: 0.8425 - val_accuracy: 0.6815 - val_loss: 0.8414
# Epoch 15/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6936 - loss: 0.8172
# Epoch 15: val_accuracy did not improve from 0.68152
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6936 - loss: 0.8172 - val_accuracy: 0.6778 - val_loss: 0.8527
# Epoch 16/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6985 - loss: 0.8063
# Epoch 16: val_accuracy improved from 0.68152 to 0.69498, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6985 - loss: 0.8063 - val_accuracy: 0.6950 - val_loss: 0.8196
# Epoch 17/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7023 - loss: 0.7919
# Epoch 17: val_accuracy improved from 0.69498 to 0.69587, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7023 - loss: 0.7919 - val_accuracy: 0.6959 - val_loss: 0.8218
# Epoch 18/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7113 - loss: 0.7719
# Epoch 18: val_accuracy improved from 0.69587 to 0.70280, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7113 - loss: 0.7719 - val_accuracy: 0.7028 - val_loss: 0.7916
# Epoch 19/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7163 - loss: 0.7680
# Epoch 19: val_accuracy did not improve from 0.70280
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7163 - loss: 0.7680 - val_accuracy: 0.6876 - val_loss: 0.8367
# Epoch 20/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7209 - loss: 0.7505
# Epoch 20: val_accuracy improved from 0.70280 to 0.70676, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7209 - loss: 0.7505 - val_accuracy: 0.7068 - val_loss: 0.7753
# Epoch 21/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7287 - loss: 0.7338
# Epoch 21: val_accuracy did not improve from 0.70676
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7287 - loss: 0.7338 - val_accuracy: 0.7038 - val_loss: 0.7988
# Epoch 22/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7328 - loss: 0.7180
# Epoch 22: val_accuracy did not improve from 0.70676
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7328 - loss: 0.7180 - val_accuracy: 0.6964 - val_loss: 0.8313
# Epoch 23/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7364 - loss: 0.7133
# Epoch 23: val_accuracy improved from 0.70676 to 0.71508, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7364 - loss: 0.7133 - val_accuracy: 0.7151 - val_loss: 0.7791
# Epoch 24/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7390 - loss: 0.7022
# Epoch 24: val_accuracy did not improve from 0.71508
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7390 - loss: 0.7022 - val_accuracy: 0.7075 - val_loss: 0.8055
# Epoch 25/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7422 - loss: 0.6917
# Epoch 25: val_accuracy did not improve from 0.71508
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7422 - loss: 0.6918 - val_accuracy: 0.7083 - val_loss: 0.7945
# Epoch 26/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7460 - loss: 0.6844
# Epoch 26: val_accuracy did not improve from 0.71508
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.7460 - loss: 0.6844 - val_accuracy: 0.7151 - val_loss: 0.7642
# Epoch 27/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7493 - loss: 0.6741
# Epoch 27: val_accuracy did not improve from 0.71508
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7493 - loss: 0.6741 - val_accuracy: 0.7016 - val_loss: 0.8243
# Epoch 28/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7562 - loss: 0.6636
# Epoch 28: val_accuracy improved from 0.71508 to 0.72943, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7562 - loss: 0.6636 - val_accuracy: 0.7294 - val_loss: 0.7278
# Epoch 29/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7633 - loss: 0.6489
# Epoch 29: val_accuracy improved from 0.72943 to 0.73686, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7633 - loss: 0.6489 - val_accuracy: 0.7369 - val_loss: 0.7272
# Epoch 30/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7638 - loss: 0.6403
# Epoch 30: val_accuracy improved from 0.73686 to 0.73834, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.7638 - loss: 0.6403 - val_accuracy: 0.7383 - val_loss: 0.7156
# Epoch 31/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7632 - loss: 0.6399
# Epoch 31: val_accuracy did not improve from 0.73834
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7632 - loss: 0.6399 - val_accuracy: 0.7372 - val_loss: 0.7122
# Epoch 32/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7690 - loss: 0.6309
# Epoch 32: val_accuracy improved from 0.73834 to 0.74131, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7690 - loss: 0.6309 - val_accuracy: 0.7413 - val_loss: 0.7077
# Epoch 33/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7697 - loss: 0.6191
# Epoch 33: val_accuracy improved from 0.74131 to 0.74339, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7697 - loss: 0.6191 - val_accuracy: 0.7434 - val_loss: 0.7024
# Epoch 34/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7750 - loss: 0.6071
# Epoch 34: val_accuracy did not improve from 0.74339
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7750 - loss: 0.6071 - val_accuracy: 0.7344 - val_loss: 0.7246
# Epoch 35/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7760 - loss: 0.5979
# Epoch 35: val_accuracy improved from 0.74339 to 0.74468, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7760 - loss: 0.5979 - val_accuracy: 0.7447 - val_loss: 0.6937
# Epoch 36/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7791 - loss: 0.5990
# Epoch 36: val_accuracy did not improve from 0.74468
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7791 - loss: 0.5990 - val_accuracy: 0.7293 - val_loss: 0.7567
# Epoch 37/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7848 - loss: 0.5818
# Epoch 37: val_accuracy improved from 0.74468 to 0.74745, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7848 - loss: 0.5818 - val_accuracy: 0.7475 - val_loss: 0.6982
# Epoch 38/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7865 - loss: 0.5748
# Epoch 38: val_accuracy did not improve from 0.74745
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.7865 - loss: 0.5748 - val_accuracy: 0.7393 - val_loss: 0.7156
# Epoch 39/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7881 - loss: 0.5817
# Epoch 39: val_accuracy improved from 0.74745 to 0.74923, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7881 - loss: 0.5817 - val_accuracy: 0.7492 - val_loss: 0.7007
# Epoch 40/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7951 - loss: 0.5624
# Epoch 40: val_accuracy did not improve from 0.74923
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7951 - loss: 0.5624 - val_accuracy: 0.7450 - val_loss: 0.7143
# Epoch 41/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7952 - loss: 0.5589
# Epoch 41: val_accuracy improved from 0.74923 to 0.75824, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7952 - loss: 0.5589 - val_accuracy: 0.7582 - val_loss: 0.6854
# Epoch 42/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7966 - loss: 0.5516
# Epoch 42: val_accuracy did not improve from 0.75824
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.7966 - loss: 0.5516 - val_accuracy: 0.7468 - val_loss: 0.7182
# Epoch 43/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7990 - loss: 0.5517
# Epoch 43: val_accuracy improved from 0.75824 to 0.76547, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7990 - loss: 0.5517 - val_accuracy: 0.7655 - val_loss: 0.6669
# Epoch 44/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8018 - loss: 0.5370
# Epoch 44: val_accuracy did not improve from 0.76547
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.8018 - loss: 0.5370 - val_accuracy: 0.7520 - val_loss: 0.7120
# Epoch 45/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8071 - loss: 0.5329
# Epoch 45: val_accuracy improved from 0.76547 to 0.76992, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.8071 - loss: 0.5329 - val_accuracy: 0.7699 - val_loss: 0.6541
# Epoch 46/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8097 - loss: 0.5193
# Epoch 46: val_accuracy did not improve from 0.76992
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 48ms/step - accuracy: 0.8097 - loss: 0.5193 - val_accuracy: 0.7620 - val_loss: 0.6785
# Epoch 47/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8053 - loss: 0.5253
# Epoch 47: val_accuracy did not improve from 0.76992
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.8053 - loss: 0.5253 - val_accuracy: 0.7681 - val_loss: 0.6529
# Epoch 48/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8135 - loss: 0.5169
# Epoch 48: val_accuracy did not improve from 0.76992
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 60s 47ms/step - accuracy: 0.8135 - loss: 0.5169 - val_accuracy: 0.7621 - val_loss: 0.6740
# Epoch 49/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8141 - loss: 0.5094
# Epoch 49: val_accuracy did not improve from 0.76992
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.8141 - loss: 0.5094 - val_accuracy: 0.7590 - val_loss: 0.6948
# Epoch 50/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8181 - loss: 0.4994
# Epoch 50: val_accuracy improved from 0.76992 to 0.77121, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.8181 - loss: 0.4994 - val_accuracy: 0.7712 - val_loss: 0.6588

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 73s 323ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.54      0.49      0.52      1024
#    disgusted       0.75      0.65      0.70       111
#        angry       0.57      0.61      0.59       958
#      neutral       0.55      0.72      0.62      1233
#          sad       0.60      0.44      0.50      1247
#    surprised       0.72      0.85      0.78       831
#        happy       0.89      0.82      0.85      1774
#
#     accuracy                           0.66      7178
#    macro avg       0.66      0.65      0.65      7178
# weighted avg       0.67      0.66      0.66      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print("Hasil Evaluasi Data Test")
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.5764 - loss: 1.4296
# Hasil Evaluasi Data Test
# Test Loss: 1.1203173398971558, Test Accuracy: 0.6613262891769409

# %%
# Langsung uji model yang sudah ada
results_train = model.evaluate(train_generator)
print("Hasil Evaluasi Data Latih")
print(f"Train Loss: {results_train[0]}, Train Accuracy: {results_train[1]}")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 46s 37ms/step - accuracy: 0.8612 - loss: 0.3810
# Hasil Evaluasi Data Latih
# Train Loss: 0.3778609037399292, Train Accuracy: 0.8631323575973511

# %%
# Langsung uji model yang sudah ada
results_val = model.evaluate(validation_generator)
print("Hasil Evaluasi Data Validasi")
print(f"Val Loss: {results_val[0]}, Val Accuracy: {results_val[1]}")
# Out:
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.7310 - loss: 0.7175
# Hasil Evaluasi Data Validasi
# Val Loss: 0.6522207260131836, Val Accuracy: 0.7691317796707153

# %%
model.save(model_name+'.keras')

# %%
model.save(model_name+'.h5')

# %%
checkpoint
