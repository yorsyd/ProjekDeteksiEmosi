# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'fearful': 7215, 'disgusted': 7215, 'surprised': 7215, 'angry': 7215, 'neutral': 7215, 'happy': 7215, 'sad': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5772, 'disgusted': 5773, 'angry': 5771, 'neutral': 5772, 'sad': 5770, 'surprised': 5773, 'happy': 5773}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # Modeling

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1
        layers.Conv2D(32, (20, 20), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(64, (20, 20), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 2
        layers.Conv2D(128, (20, 20), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(256, (20, 20), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Full Connected
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(len(classes), activation='softmax') # Mengikuti jumlah class kamu
    ])
    
    return model

model = build_final_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 48, 48, 32)     │        38,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 48, 48, 64)     │       819,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 24, 24, 128)    │     3,276,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 12, 12, 256)    │    13,107,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │     4,719,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,968,743 (83.80 MB)
#  Trainable params: 21,966,759 (83.80 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN-LargeFilter"

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# 1. Checkpoint: Simpan model terbaik secara otomatis
checkpoint = ModelCheckpoint(
    'best_emotion_model.keras', # Gunakan ekstensi .keras
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 2. Learning Rate Scheduler: Menurunkan LR jika akurasi stagnan
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=0.00001,
    verbose=1
)

# Define the callback
early_stopping = EarlyStopping(
    monitor='val_loss',      # Metric to monitor
    patience=5,              # Number of epochs with no improvement
    restore_best_weights=True, # Restores model weights from the best epoch
    verbose=1
)

# Gabungkan callbacks
callbacks_list = [checkpoint, lr_scheduler, early_stopping]

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777370914.054610     126 service.cc:152] XLA service 0x79a038002b10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777370914.054654     126 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1777370914.787382     126 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-28 10:08:40.216246: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.5 = (f32[32,32,49,49]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,48,48]{3,2,1,0} %bitcast.16344, f32[64,32,20,20]{3,2,1,0} %bitcast.14881), window={size=20x20 pad=9_9x9_9}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1_1/conv2d_9_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-04-28 10:08:41.598138: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.382042833s
# Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.5 = (f32[32,32,49,49]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,48,48]{3,2,1,0} %bitcast.16344, f32[64,32,20,20]{3,2,1,0} %bitcast.14881), window={size=20x20 pad=9_9x9_9}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1_1/conv2d_9_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
#    5/1263 ━━━━━━━━━━━━━━━━━━━━ 48s 39ms/step - accuracy: 0.1801 - loss: 3.8749
# I0000 00:00:1777370929.553775     126 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  829/1263 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 0.1629 - loss: 2.5407
# 2026-04-28 10:09:27.415154: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.5 = (f32[20,32,49,49]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,64,48,48]{3,2,1,0} %bitcast.16344, f32[64,32,20,20]{3,2,1,0} %bitcast.14881), window={size=20x20 pad=9_9x9_9}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1_1/conv2d_9_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 2026-04-28 10:09:27.737349: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.322286697s
# Trying algorithm eng2{k2=3,k3=0} for conv %cudnn-conv-bw-input.5 = (f32[20,32,49,49]{3,2,1,0}, u8[0]{0}) custom-call(f32[20,64,48,48]{3,2,1,0} %bitcast.16344, f32[64,32,20,20]{3,2,1,0} %bitcast.14881), window={size=20x20 pad=9_9x9_9}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", metadata={op_type="Conv2DBackpropInput" op_name="gradient_tape/sequential_1_1/conv2d_9_1/convolution/Conv2DBackpropInput" source_file="/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false} is taking a while...
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.1652 - loss: 2.4426
# Epoch 1: val_accuracy improved from -inf to 0.20978, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 99s 63ms/step - accuracy: 0.1652 - loss: 2.4424 - val_accuracy: 0.2098 - val_loss: 1.9681 - learning_rate: 0.0010
# Epoch 2/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2091 - loss: 1.9654
# Epoch 2: val_accuracy improved from 0.20978 to 0.25126, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.2091 - loss: 1.9654 - val_accuracy: 0.2513 - val_loss: 1.8542 - learning_rate: 0.0010
# Epoch 3/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2691 - loss: 1.8473
# Epoch 3: val_accuracy did not improve from 0.25126
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 49ms/step - accuracy: 0.2692 - loss: 1.8472 - val_accuracy: 0.2379 - val_loss: 2.0235 - learning_rate: 0.0010
# Epoch 4/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.3146 - loss: 1.7524
# Epoch 4: val_accuracy improved from 0.25126 to 0.32314, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.3146 - loss: 1.7524 - val_accuracy: 0.3231 - val_loss: 1.7663 - learning_rate: 0.0010
# Epoch 5/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3574 - loss: 1.6662
# Epoch 5: val_accuracy improved from 0.32314 to 0.38036, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 50ms/step - accuracy: 0.3574 - loss: 1.6662 - val_accuracy: 0.3804 - val_loss: 1.6035 - learning_rate: 0.0010
# Epoch 6/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.3950 - loss: 1.5792
# Epoch 6: val_accuracy improved from 0.38036 to 0.43926, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.3950 - loss: 1.5792 - val_accuracy: 0.4393 - val_loss: 1.4722 - learning_rate: 0.0010
# Epoch 7/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4271 - loss: 1.4990
# Epoch 7: val_accuracy improved from 0.43926 to 0.45738, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.4271 - loss: 1.4990 - val_accuracy: 0.4574 - val_loss: 1.4216 - learning_rate: 0.0010
# Epoch 8/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4570 - loss: 1.4194
# Epoch 8: val_accuracy improved from 0.45738 to 0.48243, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 52ms/step - accuracy: 0.4570 - loss: 1.4194 - val_accuracy: 0.4824 - val_loss: 1.3595 - learning_rate: 0.0010
# Epoch 9/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4815 - loss: 1.3614
# Epoch 9: val_accuracy improved from 0.48243 to 0.51005, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.4815 - loss: 1.3613 - val_accuracy: 0.5100 - val_loss: 1.2801 - learning_rate: 0.0010
# Epoch 10/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5109 - loss: 1.2925
# Epoch 10: val_accuracy improved from 0.51005 to 0.52569, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.5109 - loss: 1.2926 - val_accuracy: 0.5257 - val_loss: 1.2434 - learning_rate: 0.0010
# Epoch 11/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5305 - loss: 1.2383
# Epoch 11: val_accuracy improved from 0.52569 to 0.54747, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.5305 - loss: 1.2383 - val_accuracy: 0.5475 - val_loss: 1.1873 - learning_rate: 0.0010
# Epoch 12/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5408 - loss: 1.2104
# Epoch 12: val_accuracy improved from 0.54747 to 0.56400, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.5408 - loss: 1.2103 - val_accuracy: 0.5640 - val_loss: 1.1565 - learning_rate: 0.0010
# Epoch 13/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5596 - loss: 1.1680
# Epoch 13: val_accuracy improved from 0.56400 to 0.56450, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.5596 - loss: 1.1680 - val_accuracy: 0.5645 - val_loss: 1.1362 - learning_rate: 0.0010
# Epoch 14/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5771 - loss: 1.1326
# Epoch 14: val_accuracy improved from 0.56450 to 0.57034, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.5771 - loss: 1.1326 - val_accuracy: 0.5703 - val_loss: 1.1362 - learning_rate: 0.0010
# Epoch 15/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5817 - loss: 1.1053
# Epoch 15: val_accuracy improved from 0.57034 to 0.60311, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.5817 - loss: 1.1053 - val_accuracy: 0.6031 - val_loss: 1.0628 - learning_rate: 0.0010
# Epoch 16/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5935 - loss: 1.0763
# Epoch 16: val_accuracy did not improve from 0.60311
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 50ms/step - accuracy: 0.5935 - loss: 1.0763 - val_accuracy: 0.6023 - val_loss: 1.0533 - learning_rate: 0.0010
# Epoch 17/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6081 - loss: 1.0416
# Epoch 17: val_accuracy did not improve from 0.60311
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.6081 - loss: 1.0416 - val_accuracy: 0.5962 - val_loss: 1.0647 - learning_rate: 0.0010
# Epoch 18/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.6182 - loss: 1.0189
# Epoch 18: val_accuracy improved from 0.60311 to 0.61667, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.6182 - loss: 1.0189 - val_accuracy: 0.6167 - val_loss: 1.0152 - learning_rate: 0.0010
# Epoch 19/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6296 - loss: 0.9923
# Epoch 19: val_accuracy did not improve from 0.61667
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.6296 - loss: 0.9923 - val_accuracy: 0.6059 - val_loss: 1.0289 - learning_rate: 0.0010
# Epoch 20/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6356 - loss: 0.9752
# Epoch 20: val_accuracy improved from 0.61667 to 0.62964, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.6356 - loss: 0.9752 - val_accuracy: 0.6296 - val_loss: 0.9865 - learning_rate: 0.0010
# Epoch 21/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6459 - loss: 0.9594
# Epoch 21: val_accuracy improved from 0.62964 to 0.63598, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.6459 - loss: 0.9594 - val_accuracy: 0.6360 - val_loss: 0.9650 - learning_rate: 0.0010
# Epoch 22/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6544 - loss: 0.9280
# Epoch 22: val_accuracy improved from 0.63598 to 0.64588, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.6544 - loss: 0.9280 - val_accuracy: 0.6459 - val_loss: 0.9563 - learning_rate: 0.0010
# Epoch 23/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6612 - loss: 0.9098
# Epoch 23: val_accuracy did not improve from 0.64588
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.6612 - loss: 0.9099 - val_accuracy: 0.6320 - val_loss: 0.9651 - learning_rate: 0.0010
# Epoch 24/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6729 - loss: 0.8877
# Epoch 24: val_accuracy did not improve from 0.64588
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.6729 - loss: 0.8877 - val_accuracy: 0.6452 - val_loss: 0.9415 - learning_rate: 0.0010
# Epoch 25/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6800 - loss: 0.8693
# Epoch 25: val_accuracy improved from 0.64588 to 0.65093, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.6800 - loss: 0.8693 - val_accuracy: 0.6509 - val_loss: 0.9345 - learning_rate: 0.0010
# Epoch 26/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6834 - loss: 0.8638
# Epoch 26: val_accuracy improved from 0.65093 to 0.66142, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 66s 52ms/step - accuracy: 0.6834 - loss: 0.8638 - val_accuracy: 0.6614 - val_loss: 0.9152 - learning_rate: 0.0010
# Epoch 27/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6902 - loss: 0.8373
# Epoch 27: val_accuracy did not improve from 0.66142
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.6902 - loss: 0.8374 - val_accuracy: 0.6570 - val_loss: 0.9118 - learning_rate: 0.0010
# Epoch 28/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6923 - loss: 0.8306
# Epoch 28: val_accuracy improved from 0.66142 to 0.66597, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.6923 - loss: 0.8306 - val_accuracy: 0.6660 - val_loss: 0.8848 - learning_rate: 0.0010
# Epoch 29/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6994 - loss: 0.8177
# Epoch 29: val_accuracy improved from 0.66597 to 0.67350, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 50ms/step - accuracy: 0.6994 - loss: 0.8177 - val_accuracy: 0.6735 - val_loss: 0.8859 - learning_rate: 0.0010
# Epoch 30/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7076 - loss: 0.8005
# Epoch 30: val_accuracy improved from 0.67350 to 0.68043, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.7076 - loss: 0.8005 - val_accuracy: 0.6804 - val_loss: 0.8720 - learning_rate: 0.0010
# Epoch 31/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7126 - loss: 0.7791
# Epoch 31: val_accuracy did not improve from 0.68043
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7126 - loss: 0.7791 - val_accuracy: 0.6761 - val_loss: 0.8740 - learning_rate: 0.0010
# Epoch 32/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7132 - loss: 0.7804
# Epoch 32: val_accuracy improved from 0.68043 to 0.69211, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.7132 - loss: 0.7804 - val_accuracy: 0.6921 - val_loss: 0.8475 - learning_rate: 0.0010
# Epoch 33/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7256 - loss: 0.7519
# Epoch 33: val_accuracy did not improve from 0.69211
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.7256 - loss: 0.7519 - val_accuracy: 0.6827 - val_loss: 0.8623 - learning_rate: 0.0010
# Epoch 34/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7245 - loss: 0.7541
# Epoch 34: val_accuracy did not improve from 0.69211
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 62s 49ms/step - accuracy: 0.7245 - loss: 0.7541 - val_accuracy: 0.6897 - val_loss: 0.8532 - learning_rate: 0.0010
# Epoch 35/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7304 - loss: 0.7384
# Epoch 35: val_accuracy improved from 0.69211 to 0.69746, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 50ms/step - accuracy: 0.7304 - loss: 0.7384 - val_accuracy: 0.6975 - val_loss: 0.8309 - learning_rate: 0.0010
# Epoch 36/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7371 - loss: 0.7162
# Epoch 36: val_accuracy did not improve from 0.69746
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.7371 - loss: 0.7162 - val_accuracy: 0.6950 - val_loss: 0.8376 - learning_rate: 0.0010
# Epoch 37/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7472 - loss: 0.7000
# Epoch 37: val_accuracy improved from 0.69746 to 0.69953, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 50ms/step - accuracy: 0.7472 - loss: 0.7000 - val_accuracy: 0.6995 - val_loss: 0.8237 - learning_rate: 0.0010
# Epoch 38/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7500 - loss: 0.6911
# Epoch 38: val_accuracy did not improve from 0.69953
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.7500 - loss: 0.6911 - val_accuracy: 0.6903 - val_loss: 0.8453 - learning_rate: 0.0010
# Epoch 39/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7472 - loss: 0.6935
# Epoch 39: val_accuracy improved from 0.69953 to 0.70052, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 52ms/step - accuracy: 0.7472 - loss: 0.6935 - val_accuracy: 0.7005 - val_loss: 0.8277 - learning_rate: 0.0010
# Epoch 40/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7507 - loss: 0.6811
# Epoch 40: val_accuracy improved from 0.70052 to 0.70310, saving model to best_emotion_model.keras
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.7507 - loss: 0.6811 - val_accuracy: 0.7031 - val_loss: 0.8251 - learning_rate: 0.0010
# Epoch 41/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7742 - loss: 0.6249
# Epoch 41: val_accuracy improved from 0.70310 to 0.73607, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.7742 - loss: 0.6249 - val_accuracy: 0.7361 - val_loss: 0.7475 - learning_rate: 2.0000e-04
# Epoch 42/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7863 - loss: 0.5949
# Epoch 42: val_accuracy did not improve from 0.73607
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.7863 - loss: 0.5949 - val_accuracy: 0.7355 - val_loss: 0.7496 - learning_rate: 2.0000e-04
# Epoch 43/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7885 - loss: 0.5822
# Epoch 43: val_accuracy improved from 0.73607 to 0.73755, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 66s 52ms/step - accuracy: 0.7885 - loss: 0.5822 - val_accuracy: 0.7376 - val_loss: 0.7420 - learning_rate: 2.0000e-04
# Epoch 44/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7900 - loss: 0.5783
# Epoch 44: val_accuracy improved from 0.73755 to 0.74696, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.7900 - loss: 0.5783 - val_accuracy: 0.7470 - val_loss: 0.7234 - learning_rate: 2.0000e-04
# Epoch 45/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8053 - loss: 0.5547
# Epoch 45: val_accuracy did not improve from 0.74696
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.8053 - loss: 0.5547 - val_accuracy: 0.7453 - val_loss: 0.7198 - learning_rate: 2.0000e-04
# Epoch 46/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8060 - loss: 0.5376
# Epoch 46: val_accuracy did not improve from 0.74696
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.8060 - loss: 0.5376 - val_accuracy: 0.7419 - val_loss: 0.7336 - learning_rate: 2.0000e-04
# Epoch 47/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8087 - loss: 0.5382
# Epoch 47: val_accuracy improved from 0.74696 to 0.74993, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 64s 51ms/step - accuracy: 0.8087 - loss: 0.5382 - val_accuracy: 0.7499 - val_loss: 0.7195 - learning_rate: 2.0000e-04
# Epoch 48/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8105 - loss: 0.5300
# Epoch 48: val_accuracy improved from 0.74993 to 0.75012, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 51ms/step - accuracy: 0.8105 - loss: 0.5300 - val_accuracy: 0.7501 - val_loss: 0.7263 - learning_rate: 2.0000e-04
# Epoch 49/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8191 - loss: 0.5115
# Epoch 49: val_accuracy did not improve from 0.75012
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 52ms/step - accuracy: 0.8191 - loss: 0.5115 - val_accuracy: 0.7491 - val_loss: 0.7124 - learning_rate: 2.0000e-04
# Epoch 50/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8158 - loss: 0.5177
# Epoch 50: val_accuracy improved from 0.75012 to 0.75052, saving model to best_emotion_model.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 65s 52ms/step - accuracy: 0.8158 - loss: 0.5177 - val_accuracy: 0.7505 - val_loss: 0.7115 - learning_rate: 2.0000e-04
# Restoring model weights from the end of the best epoch: 50.

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 791ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 57s 251ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.53      0.46      0.49      1024
#    disgusted       0.69      0.67      0.68       111
#        angry       0.50      0.57      0.53       958
#      neutral       0.54      0.58      0.56      1233
#          sad       0.51      0.49      0.50      1247
#    surprised       0.74      0.81      0.78       831
#        happy       0.83      0.77      0.80      1774
#
#     accuracy                           0.62      7178
#    macro avg       0.62      0.62      0.62      7178
# weighted avg       0.63      0.62      0.62      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.5361 - loss: 1.5277
# Test Loss: 1.2203478813171387, Test Accuracy: 0.622178852558136

# %%
model.save('CNN-LargeFilter.keras')

# %%
model.save('CNN-LargeFilter.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
