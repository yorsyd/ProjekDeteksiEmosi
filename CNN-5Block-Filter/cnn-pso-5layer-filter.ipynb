# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-05-18 02:31:41.944336: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779071502.152349      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779071502.208761      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779071502.650860      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779071502.650908      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779071502.650911      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779071502.650914      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'angry': 7215, 'fearful': 7215, 'happy': 7215, 'sad': 7215, 'neutral': 7215, 'disgusted': 7215, 'surprised': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=32

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  32   test steps:  224  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (32, 48, 48, 3)
# y_train shape:  (32, 7)
#
# X_test shape:  (32, 48, 48, 3)
# y_test shape:  (32, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5771, 'disgusted': 5772, 'angry': 5776, 'neutral': 5776, 'sad': 5769, 'surprised': 5770, 'happy': 5770}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # PSO

# %%
pip install pyswarms
# Out:
# Collecting pyswarms
#   Downloading pyswarms-1.3.0-py2.py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyswarms) (2.0.2)
# Requirement already satisfied: matplotlib>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from pyswarms) (3.10.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from pyswarms) (25.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from pyswarms) (4.67.3)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from pyswarms) (1.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pyswarms) (6.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=1.3.1->pyswarms) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=1.3.1->pyswarms) (1.17.0)
# Downloading pyswarms-1.3.0-py2.py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: pyswarms
# Successfully installed pyswarms-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
def fitness_function(params):
    results = []
    
    for p in params:
        # Ekstraksi parameter dari partikel PSO (Total 9 Dimensi sekarang)
        lr = p[0]
        f1 = int(p[1])   
        f2 = int(p[2])   
        f3 = int(p[3])   
        f4 = int(p[4])   
        f5 = int(p[5])   
        dense_u = int(p[6]) 
        dropout = p[7] 
        ukuran_filter = int(p[8])
        
        # Build model berdasarkan partikel
        model = models.Sequential([
            layers.Input(shape=(img_height, img_width, 3)),
            
            # Block 1: 48x48 -> Pool (2,2) -> 24x24
            layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(f1*2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 2: 24x24 -> Pool (2,2) -> 12x12
            layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 3: 12x12 -> Pool (2,2) -> 6x6
            layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 4: 6x6 -> Pool (2,2) -> 3x3
            layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(dropout),

            # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
            # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
            layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),

            layers.Flatten(),
            layers.Dense(dense_u, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(dropout),
            layers.Dense(len(classes), activation='softmax')
        ])
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
        
        # Evaluasi cepat 
        history = model.fit(train_generator, epochs=3, 
                            validation_data=validation_generator, 
                            verbose=0)
        
        val_acc = max(history.history['val_accuracy'])
        results.append(1 - val_acc)
        
        K.clear_session()
        del model
        gc.collect()
        
    return np.array(results)

# %%
# Batas Pencarian: [LR, F1, F2, F3, F4, F5, Dense, Dropout, Ukuran_Filter]
lb = [1e-4, 16, 32, 64, 128, 128, 128, 0.1, 3]   
ub = [1e-2, 64, 128, 256, 512, 512, 512, 0.4, 5] 

# Jalankan Optimizer dengan dimensions=9
optimizer = ps.single.GlobalBestPSO(n_particles=10, 
                                    dimensions=9, 
                                    options={'c1': 0.5, 'c2': 0.3, 'w': 0.9}, 
                                    bounds=(lb, ub))

best_cost, best_pos = optimizer.optimize(fitness_function, iters=5)
# Out:
# 2026-05-18 03:04:44,423 - pyswarms.single.global_best - INFO - Optimize for 5 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████|5/5, best_cost=0.469
# 2026-05-18 05:46:39,173 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.46856749057769775, best pos: [7.46403974e-04 3.24100988e+01 6.86094190e+01 1.09738352e+02
#  1.95575354e+02 4.70685268e+02 4.14019716e+02 1.30080859e-01
#  4.34020469e+00]

# %%
print(f"""
=== Hasil Optimasi PSO ===
Learning Rate : {best_pos[0]:.6f}
Filter 1      : {int(best_pos[1])}
Filter 2      : {int(best_pos[2])}
Filter 3      : {int(best_pos[3])}
Filter 4      : {int(best_pos[4])}
Filter 5      : {int(best_pos[5])}
Dense Units   : {int(best_pos[6])}
Dropout       : {best_pos[7]:.2f}
Ukuran Filter : {int(best_pos[8])}
""")
# Out:
# === Hasil Optimasi PSO ===
# Learning Rate : 0.000746
# Filter 1      : 32
# Filter 2      : 68
# Filter 3      : 109
# Filter 4      : 195
# Filter 5      : 470
# Dense Units   : 414
# Dropout       : 0.13
# Ukuran Filter : 4

# %%
lr_best = best_pos[0]
f1 = int(best_pos[1])
f2 = int(best_pos[2])
f3 = int(best_pos[3])
f4 = int(best_pos[4])
f5 = int(best_pos[5])
dense_u = int(best_pos[6])
dropout = best_pos[7]
ukuran_filter = int(best_pos[8])

# %% [markdown]
# # Modeling

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN-PSO-5Layer-Filter-Pooling"

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow import keras

# 1. Gunakan nilai hasil PSO langsung ke dalam Adam Optimizer
# Ganti 'lr_best' dengan variabel nilai dari PSO kamu
optimizer_pso = Adam(learning_rate=lr_best) 

# 2. Checkpoint: Cukup simpan model terbaik berdasarkan val_accuracy
checkpoint = ModelCheckpoint(
    'best_model' + model_name + '.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 3. Hapus ReduceLROnPlateau dari daftar callback agar LR tetap FIXED
callbacks_list = [checkpoint]

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1: 48x48 -> Pool (2,2) -> 24x24
        layers.Conv2D(f1, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(f1*2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 2: 24x24 -> Pool (2,2) -> 12x12
        layers.Conv2D(f2, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 3: 12x12 -> Pool (2,2) -> 6x6
        layers.Conv2D(f3, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 4: 6x6 -> Pool (2,2) -> 3x3
        layers.Conv2D(f4, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout),

        # Block 5: 3x3 -> TIDAK BOLEH pakai MaxPooling lagi karena sisa 3x3
        # Jika dipaksa pool (2,2) hasilnya akan hancur/error di layer berikutnya
        layers.Conv2D(f5, (ukuran_filter, ukuran_filter), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),

        layers.Flatten(),
        layers.Dense(dense_u, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(dropout),
        layers.Dense(len(classes), activation='softmax')
    ])
    
    return model

# %%
model = build_final_model()
model.compile(optimizer=optimizer_pso, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 48, 48, 32)     │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 48, 48, 64)     │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 24, 24, 68)     │        69,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 24, 24, 68)     │           272 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 12, 12, 68)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 12, 12, 68)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 12, 12, 109)    │       118,701 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 12, 12, 109)    │           436 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 6, 6, 109)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 6, 6, 109)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 195)      │       340,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 195)      │           780 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 3, 3, 195)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 195)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 3, 3, 470)      │     1,466,870 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 3, 3, 470)      │         1,880 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 3, 3, 470)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4230)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 414)            │     1,751,634 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 414)            │         1,656 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 414)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │         2,905 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,789,893 (14.46 MB)
#  Trainable params: 3,787,189 (14.45 MB)
#  Non-trainable params: 2,704 (10.56 KB)

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_model_cnn_pos_5_filter.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2252 - loss: 2.0418
# Epoch 1: val_accuracy improved from -inf to 0.21394, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 80s 53ms/step - accuracy: 0.2252 - loss: 2.0417 - val_accuracy: 0.2139 - val_loss: 2.0893
# Epoch 2/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3993 - loss: 1.5868
# Epoch 2: val_accuracy improved from 0.21394 to 0.42283, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.3993 - loss: 1.5868 - val_accuracy: 0.4228 - val_loss: 1.6229
# Epoch 3/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4892 - loss: 1.3533
# Epoch 3: val_accuracy improved from 0.42283 to 0.53024, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.4892 - loss: 1.3533 - val_accuracy: 0.5302 - val_loss: 1.2405
# Epoch 4/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5324 - loss: 1.2490
# Epoch 4: val_accuracy improved from 0.53024 to 0.56618, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5324 - loss: 1.2489 - val_accuracy: 0.5662 - val_loss: 1.1528
# Epoch 5/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5583 - loss: 1.1686
# Epoch 5: val_accuracy did not improve from 0.56618
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5583 - loss: 1.1685 - val_accuracy: 0.5445 - val_loss: 1.1968
# Epoch 6/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5777 - loss: 1.1242
# Epoch 6: val_accuracy improved from 0.56618 to 0.58054, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.5777 - loss: 1.1242 - val_accuracy: 0.5805 - val_loss: 1.0916
# Epoch 7/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6026 - loss: 1.0619
# Epoch 7: val_accuracy improved from 0.58054 to 0.62261, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6026 - loss: 1.0620 - val_accuracy: 0.6226 - val_loss: 1.0046
# Epoch 8/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6119 - loss: 1.0358
# Epoch 8: val_accuracy did not improve from 0.62261
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6119 - loss: 1.0358 - val_accuracy: 0.6191 - val_loss: 1.0090
# Epoch 9/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6199 - loss: 1.0109
# Epoch 9: val_accuracy did not improve from 0.62261
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6199 - loss: 1.0109 - val_accuracy: 0.5960 - val_loss: 1.1251
# Epoch 10/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6287 - loss: 0.9880
# Epoch 10: val_accuracy improved from 0.62261 to 0.64093, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6287 - loss: 0.9880 - val_accuracy: 0.6409 - val_loss: 0.9518
# Epoch 11/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6436 - loss: 0.9545
# Epoch 11: val_accuracy improved from 0.64093 to 0.65568, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6436 - loss: 0.9545 - val_accuracy: 0.6557 - val_loss: 0.9274
# Epoch 12/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6407 - loss: 0.9498
# Epoch 12: val_accuracy improved from 0.65568 to 0.66261, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6407 - loss: 0.9498 - val_accuracy: 0.6626 - val_loss: 0.8962
# Epoch 13/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6568 - loss: 0.9130
# Epoch 13: val_accuracy did not improve from 0.66261
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6568 - loss: 0.9130 - val_accuracy: 0.6619 - val_loss: 0.8956
# Epoch 14/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6661 - loss: 0.8963
# Epoch 14: val_accuracy did not improve from 0.66261
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.6661 - loss: 0.8963 - val_accuracy: 0.6468 - val_loss: 0.9544
# Epoch 15/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6665 - loss: 0.8812
# Epoch 15: val_accuracy improved from 0.66261 to 0.68241, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6665 - loss: 0.8812 - val_accuracy: 0.6824 - val_loss: 0.8522
# Epoch 16/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6734 - loss: 0.8691
# Epoch 16: val_accuracy improved from 0.68241 to 0.68320, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.6734 - loss: 0.8691 - val_accuracy: 0.6832 - val_loss: 0.8411
# Epoch 17/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6829 - loss: 0.8504
# Epoch 17: val_accuracy did not improve from 0.68320
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.6829 - loss: 0.8504 - val_accuracy: 0.6677 - val_loss: 0.8821
# Epoch 18/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6808 - loss: 0.8469
# Epoch 18: val_accuracy did not improve from 0.68320
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.6808 - loss: 0.8469 - val_accuracy: 0.6744 - val_loss: 0.8787
# Epoch 19/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6882 - loss: 0.8230
# Epoch 19: val_accuracy did not improve from 0.68320
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.6882 - loss: 0.8230 - val_accuracy: 0.6628 - val_loss: 0.9215
# Epoch 20/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6907 - loss: 0.8189
# Epoch 20: val_accuracy improved from 0.68320 to 0.69488, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.6907 - loss: 0.8189 - val_accuracy: 0.6949 - val_loss: 0.8097
# Epoch 21/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7057 - loss: 0.7908
# Epoch 21: val_accuracy improved from 0.69488 to 0.69518, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 61s 48ms/step - accuracy: 0.7057 - loss: 0.7908 - val_accuracy: 0.6952 - val_loss: 0.8203
# Epoch 22/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7025 - loss: 0.7895
# Epoch 22: val_accuracy did not improve from 0.69518
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 55s 44ms/step - accuracy: 0.7025 - loss: 0.7895 - val_accuracy: 0.6919 - val_loss: 0.8181
# Epoch 23/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7105 - loss: 0.7712
# Epoch 23: val_accuracy improved from 0.69518 to 0.69696, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 47ms/step - accuracy: 0.7105 - loss: 0.7713 - val_accuracy: 0.6970 - val_loss: 0.8010
# Epoch 24/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7126 - loss: 0.7611
# Epoch 24: val_accuracy improved from 0.69696 to 0.70072, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7126 - loss: 0.7611 - val_accuracy: 0.7007 - val_loss: 0.7995
# Epoch 25/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7109 - loss: 0.7635
# Epoch 25: val_accuracy improved from 0.70072 to 0.71141, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7109 - loss: 0.7635 - val_accuracy: 0.7114 - val_loss: 0.7710
# Epoch 26/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7197 - loss: 0.7448
# Epoch 26: val_accuracy improved from 0.71141 to 0.71330, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7197 - loss: 0.7448 - val_accuracy: 0.7133 - val_loss: 0.7788
# Epoch 27/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7230 - loss: 0.7324
# Epoch 27: val_accuracy did not improve from 0.71330
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7230 - loss: 0.7324 - val_accuracy: 0.7090 - val_loss: 0.7852
# Epoch 28/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7314 - loss: 0.7231
# Epoch 28: val_accuracy improved from 0.71330 to 0.72379, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7313 - loss: 0.7231 - val_accuracy: 0.7238 - val_loss: 0.7497
# Epoch 29/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7337 - loss: 0.7097
# Epoch 29: val_accuracy improved from 0.72379 to 0.72844, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7337 - loss: 0.7097 - val_accuracy: 0.7284 - val_loss: 0.7440
# Epoch 30/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7405 - loss: 0.6966
# Epoch 30: val_accuracy did not improve from 0.72844
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.7405 - loss: 0.6966 - val_accuracy: 0.7259 - val_loss: 0.7352
# Epoch 31/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7389 - loss: 0.6977
# Epoch 31: val_accuracy did not improve from 0.72844
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7389 - loss: 0.6977 - val_accuracy: 0.7224 - val_loss: 0.7621
# Epoch 32/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7423 - loss: 0.6835
# Epoch 32: val_accuracy did not improve from 0.72844
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7423 - loss: 0.6835 - val_accuracy: 0.7174 - val_loss: 0.7463
# Epoch 33/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7527 - loss: 0.6627
# Epoch 33: val_accuracy improved from 0.72844 to 0.72904, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7527 - loss: 0.6627 - val_accuracy: 0.7290 - val_loss: 0.7306
# Epoch 34/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7511 - loss: 0.6730
# Epoch 34: val_accuracy improved from 0.72904 to 0.73062, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7511 - loss: 0.6730 - val_accuracy: 0.7306 - val_loss: 0.7305
# Epoch 35/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7509 - loss: 0.6724
# Epoch 35: val_accuracy improved from 0.73062 to 0.73715, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 59s 46ms/step - accuracy: 0.7509 - loss: 0.6724 - val_accuracy: 0.7372 - val_loss: 0.7157
# Epoch 36/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7556 - loss: 0.6518
# Epoch 36: val_accuracy did not improve from 0.73715
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7556 - loss: 0.6518 - val_accuracy: 0.7133 - val_loss: 0.7853
# Epoch 37/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7610 - loss: 0.6447
# Epoch 37: val_accuracy improved from 0.73715 to 0.73884, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7610 - loss: 0.6447 - val_accuracy: 0.7388 - val_loss: 0.7137
# Epoch 38/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7622 - loss: 0.6372
# Epoch 38: val_accuracy did not improve from 0.73884
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 44ms/step - accuracy: 0.7622 - loss: 0.6372 - val_accuracy: 0.7249 - val_loss: 0.7471
# Epoch 39/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7656 - loss: 0.6300
# Epoch 39: val_accuracy improved from 0.73884 to 0.74191, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7656 - loss: 0.6300 - val_accuracy: 0.7419 - val_loss: 0.7007
# Epoch 40/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7704 - loss: 0.6225
# Epoch 40: val_accuracy improved from 0.74191 to 0.74468, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 56s 45ms/step - accuracy: 0.7704 - loss: 0.6225 - val_accuracy: 0.7447 - val_loss: 0.6893
# Epoch 41/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7743 - loss: 0.6191
# Epoch 41: val_accuracy improved from 0.74468 to 0.75092, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7743 - loss: 0.6191 - val_accuracy: 0.7509 - val_loss: 0.6929
# Epoch 42/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7686 - loss: 0.6186
# Epoch 42: val_accuracy did not improve from 0.75092
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 46ms/step - accuracy: 0.7686 - loss: 0.6186 - val_accuracy: 0.7450 - val_loss: 0.7105
# Epoch 43/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7752 - loss: 0.6098
# Epoch 43: val_accuracy did not improve from 0.75092
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7752 - loss: 0.6098 - val_accuracy: 0.7501 - val_loss: 0.6889
# Epoch 44/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7757 - loss: 0.6073
# Epoch 44: val_accuracy did not improve from 0.75092
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.7757 - loss: 0.6073 - val_accuracy: 0.7500 - val_loss: 0.7023
# Epoch 45/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7847 - loss: 0.5844
# Epoch 45: val_accuracy improved from 0.75092 to 0.75389, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 58s 46ms/step - accuracy: 0.7847 - loss: 0.5845 - val_accuracy: 0.7539 - val_loss: 0.6794
# Epoch 46/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7879 - loss: 0.5794
# Epoch 46: val_accuracy did not improve from 0.75389
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 63s 50ms/step - accuracy: 0.7879 - loss: 0.5794 - val_accuracy: 0.7521 - val_loss: 0.6933
# Epoch 47/50
# 1262/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7906 - loss: 0.5752
# Epoch 47: val_accuracy improved from 0.75389 to 0.76091, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 67s 53ms/step - accuracy: 0.7906 - loss: 0.5752 - val_accuracy: 0.7609 - val_loss: 0.6799
# Epoch 48/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7891 - loss: 0.5777
# Epoch 48: val_accuracy did not improve from 0.76091
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 70s 55ms/step - accuracy: 0.7891 - loss: 0.5777 - val_accuracy: 0.7577 - val_loss: 0.6824
# Epoch 49/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7886 - loss: 0.5692
# Epoch 49: val_accuracy did not improve from 0.76091
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 69s 55ms/step - accuracy: 0.7886 - loss: 0.5692 - val_accuracy: 0.7601 - val_loss: 0.6666
# Epoch 50/50
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7896 - loss: 0.5696
# Epoch 50: val_accuracy improved from 0.76091 to 0.76418, saving model to best_modelCNN-PSO-5Layer-Filter-Pooling.keras
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 70s 56ms/step - accuracy: 0.7896 - loss: 0.5696 - val_accuracy: 0.7642 - val_loss: 0.6696

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 69s 302ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.56      0.43      0.49      1024
#    disgusted       0.66      0.71      0.69       111
#        angry       0.58      0.59      0.59       958
#      neutral       0.58      0.68      0.63      1233
#          sad       0.54      0.55      0.55      1247
#    surprised       0.74      0.84      0.79       831
#        happy       0.90      0.83      0.86      1774
#
#     accuracy                           0.67      7178
#    macro avg       0.65      0.66      0.65      7178
# weighted avg       0.67      0.67      0.67      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print("Hasil Evaluasi Data Test")
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - accuracy: 0.5568 - loss: 1.4153
# Hasil Evaluasi Data Test
# Test Loss: 1.0554516315460205, Test Accuracy: 0.6666202545166016

# %%
# Langsung uji model yang sudah ada
results_train = model.evaluate(train_generator)
print("Hasil Evaluasi Data Latih")
print(f"Train Loss: {results_train[0]}, Train Accuracy: {results_train[1]}")
# Out:
# 1263/1263 ━━━━━━━━━━━━━━━━━━━━ 57s 45ms/step - accuracy: 0.8560 - loss: 0.3969
# Hasil Evaluasi Data Latih
# Train Loss: 0.3944419026374817, Train Accuracy: 0.8580338358879089

# %%
# Langsung uji model yang sudah ada
results_val = model.evaluate(validation_generator)
print("Hasil Evaluasi Data Validasi")
print(f"Val Loss: {results_val[0]}, Val Accuracy: {results_val[1]}")
# Out:
# 316/316 ━━━━━━━━━━━━━━━━━━━━ 14s 45ms/step - accuracy: 0.7206 - loss: 0.7635
# Hasil Evaluasi Data Validasi
# Val Loss: 0.6616382002830505, Val Accuracy: 0.7722997665405273

# %% [markdown]
# Checkpoint

# %%
# Langsung uji model yang sudah ada
results = checkpoint.evaluate(test_generator)
print("Hasil Evaluasi Data Test")
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_57/3930682697.py in <cell line: 0>()
#       1 # Langsung uji model yang sudah ada
# ----> 2 results = checkpoint.evaluate(test_generator)
#       3 print("Hasil Evaluasi Data Test")
#       4 print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
#
# AttributeError: 'ModelCheckpoint' object has no attribute 'evaluate'

# %%
# Langsung uji model yang sudah ada
results_train = checkpoint.evaluate(train_generator)
print("Hasil Evaluasi Data Latih")
print(f"Train Loss: {results_train[0]}, Train Accuracy: {results_train[1]}")

# %%
# Langsung uji model yang sudah ada
results_val = checkpoint.evaluate(validation_generator)
print("Hasil Evaluasi Data Validasi")
print(f"Val Loss: {results_val[0]}, Val Accuracy: {results_val[1]}")

# %%
model.save(model_name+'.keras')

# %%
model.save(model_name+'.h5')

# %%
checkpoint
