# %% [markdown]
# # Persiapan

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as npy # linear algebra
import pandas as pds # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator as ImgDataGen

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
# Out:
# 2026-04-29 02:49:23.568156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777430963.756117      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777430963.811206      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777430964.243249      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777430964.243307      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777430964.243310      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777430964.243312      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# Specify important directories
import os, sys, time, warnings, sklearn
ROOT='/kaggle/input'
# ROOT='data'
TEST_PATH= "/kaggle/input/datasets/ananthu017/emotion-detection-fer/test"
TRAIN_PATH='/kaggle/input/datasets/ananthu017/emotion-detection-fer/train'

train_angry_img_path=TRAIN_PATH +'/angry'

OVERSAMPLED_TRAIN_PATH='fed_oversampled_train'
MODEL_PATH='models'
IMAGE_PATH='images'

# %% [markdown]
# # EDA

# %%
# Load a sample image 
# using open() to open images
image_data = Image.open(train_angry_img_path+'/im0.png')
image_data
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=48x48>

# %%
# Get the shape of the image
image=plt.imread(train_angry_img_path+'/im0.png')
print(f'Image shape: {image.shape}')

# Convert image data (like jpeg) to numpy using asarray()
image_array = npy.asarray(image_data)
print(f'Image data array: {image_array}')

# Get the shape of the image array
print(f'Image array shape: {image_array.shape}')

# Printing the image 
plt.imshow(image_array)
plt.xlabel('Width')
plt.ylabel('Height')
plt.title('An Angry Face')
plt.show()
# Out:
# Image shape: (48, 48)
# Image data array: [[ 70  80  82 ...  52  43  41]
#  [ 65  61  58 ...  56  52  44]
#  [ 50  43  54 ...  49  56  47]
#  ...
#  [ 91  65  42 ...  72  56  43]
#  [ 77  82  79 ... 105  70  46]
#  [ 77  72  84 ... 106 109  82]]
# Image array shape: (48, 48)

# %%
# Get the list of folders in the directory as classes
classes=os.listdir(TRAIN_PATH+'/')
classes
# Out:
# ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']

# %%
# Get dictionary list of image count per class
def class_sample(type):
    if type.lower() == 'test' or type.lower() == 'train':
        path=''
        if type.lower() == 'train':    
            path= TRAIN_PATH
        else:
            path= TEST_PATH
        
        filepath=path+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict
    else:
        raise ValueError('Invalid type. Must be "test" or "train".')


def test_train_distribution():
      print("---- Train Set ----")
      avg_train=class_sample('train')[0]/len(class_sample('train')[1])
      print(f'Train class distribution:\n{class_sample("train")[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', class_sample('train')[0])

      print("\n---- Test Set ----")
      avg_test=class_sample('test')[0]/len(class_sample('test')[1])
      print(f'Test class distribution:\n{class_sample("test")[2]}')
      print("Average test class: ",round(avg_test)) 
      print('Total test: ', class_sample('test')[0])


test_train_distribution()
# Out:
# ---- Train Set ----
# Train class distribution:
# {'fearful': 4097, 'disgusted': 436, 'angry': 3995, 'neutral': 4965, 'sad': 4830, 'surprised': 3171, 'happy': 7215}
# Average train class:  4101
# Total train:  28709
#
# ---- Test Set ----
# Test class distribution:
# {'fearful': 1024, 'disgusted': 111, 'angry': 958, 'neutral': 1233, 'sad': 1247, 'surprised': 831, 'happy': 1774}
# Average test class:  1025
# Total test:  7178

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Oversampling

# %%
# Oversampling Technique
import os
from PIL import Image

# Define the paths to the original and oversampled dataset
train_dir = TRAIN_PATH
oversampled_dir = OVERSAMPLED_TRAIN_PATH

target_length = 7215 # highest count in a class
# target_length = 4101 Average

if not os.path.exists(oversampled_dir):
    os.mkdir(oversampled_dir)

for subfolder in os.listdir(train_dir):
    subfolder_path = os.path.join(train_dir, subfolder)
    if os.path.isdir(subfolder_path):
        num_images = len(os.listdir(subfolder_path))
        num_duplicates = target_length // num_images
        remainder = target_length % num_images

        for i in range(num_duplicates):
            for image_file in os.listdir(subfolder_path):
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{i}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

        if remainder != 0:
            for image_file in os.listdir(subfolder_path)[:remainder]:
                image_path = os.path.join(subfolder_path, image_file)
                image = Image.open(image_path)
                new_image_file = f"{num_duplicates}_{image_file}"
                new_image_path = os.path.join(oversampled_dir, subfolder, new_image_file)
                if not os.path.exists(os.path.join(oversampled_dir, subfolder)):
                    os.mkdir(os.path.join(oversampled_dir, subfolder))
                image.save(new_image_path)

# %%
# Get dictionary list of image count per class
def over_class_sample():
        filepath=OVERSAMPLED_TRAIN_PATH+'/'
        class_count = []
        class_dict ={}
        for folder in os.listdir(filepath) :
              class_count.append(len(os.listdir(filepath+folder)))
              class_dict[folder]=len(os.listdir(filepath+folder))
        class_total = sum(class_count)
        return class_total, class_count, class_dict

# %%
def test_train_distribution():
      print("\n---- Oversampled Train Set ----")
      avg_train=over_class_sample()[0]/len(over_class_sample()[1])
      print(f'Train class distribution:\n{over_class_sample()[2]}')
      print("Average train class: ",round(avg_train))    
      print('Total train: ', over_class_sample()[0])



test_train_distribution()
# Out:
# ---- Oversampled Train Set ----
# Train class distribution:
# {'fearful': 7215, 'sad': 7215, 'surprised': 7215, 'disgusted': 7215, 'neutral': 7215, 'angry': 7215, 'happy': 7215}
# Average train class:  7215
# Total train:  50505

# %% [markdown]
# ## Data Augmentation

# %%
target_size=(48, 48)
# target_size=(224, 224)
batch_size=64

## Train Image Data Generator instance. 
# We will not apply any transformon specific orientations or features and no initial rescale to the image
# We'll only split the image data into train and validation set
trainValidation_data_generator = ImgDataGen(
                                    rescale=1./255,  # Gunakan 255, bukan 225
                                    rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest',
                                    validation_split=0.2
)


# Test Image Data Generator instance for Test data
test_data_generator = ImgDataGen(
                                rescale = 1./255,
                                )

# %% [markdown]
# # Data Generator

# %%
## Mapping images to their classes.
print('Train Set Generated - ',end=' ') 
train_generator = trainValidation_data_generator.flow_from_directory(
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            # directory=TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes=classes,
                                                            shuffle=True, 
                                                            subset='training' # set as training data
                                                        )
## Mapping images to their classes.
print('Validation Set Generated - ',end=' ') 
validation_generator = trainValidation_data_generator.flow_from_directory(
                                                            # directory=TRAIN_PATH, 
                                                            directory=OVERSAMPLED_TRAIN_PATH, 
                                                            target_size=target_size,
                                                            batch_size=batch_size,
                                                            class_mode='categorical', 
                                                            color_mode='rgb', 
                                                            classes= classes,
                                                            shuffle=False, 
                                                            subset='validation' # set as validation data
                                                        )
test_samples=class_sample('test')[0]
test_batch_size=batch_size
test_steps=int(test_samples/test_batch_size)

## Mapping images to their classes.
print('Test Set Generated - ',end=' ') 
test_generator = test_data_generator.flow_from_directory(
                                        directory=TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=False, 
                                        batch_size=test_batch_size
                                        )

## Mapping shuffled images to their classes.
print('Shuffled Test Set Generated - ',end=' ') 
test_generator_shuffled = test_data_generator.flow_from_directory(
                                        TEST_PATH, 
                                        target_size=target_size,
                                        class_mode='categorical', 
                                        color_mode='rgb', 
                                        classes=classes,
                                        shuffle=True, 
                                        batch_size=test_batch_size
                                        )
# Out:
# Train Set Generated -  Found 40404 images belonging to 7 classes.
# Validation Set Generated -  Found 10101 images belonging to 7 classes.
# Test Set Generated -  Found 7178 images belonging to 7 classes.
# Shuffled Test Set Generated -  Found 7178 images belonging to 7 classes.

# %%
# From the generator we can get information we will need later
# classes=  # os.listdir(TRAIN_PATH+'/')
class_dictionary = train_generator.class_indices
class_keys = list(train_generator.class_indices.keys())
class_values = list(train_generator.class_indices.values())
class_count = len(class_keys)

print ('test batch size: ' ,test_batch_size, '  test steps: ', test_steps, ' number of classes : ', class_count)

train_images, train_labels = next(train_generator)
validation_images, validation_labels = next(validation_generator)
test_images, test_labels = next(test_generator)

print(f'\nThere are 7 classes: {classes}')
print(f'The class dictionary are: {class_dictionary}')
print('Class count: ', class_count)

print('\nX_train shape: ', train_images.shape)
print('y_train shape: ', train_labels.shape)
print('\nX_test shape: ', test_images.shape)
print('y_test shape: ', test_labels.shape)

print('\ntrain_generator sample: ', train_generator.samples)
print('validation_generator sample: ', validation_generator.samples)
print('test_generator sample: ', test_generator.samples)

print('\ntrain_generator sample: ', train_generator.labels)
print('validation_generator sample: ', validation_generator.labels)
print('test_generator sample: ', test_generator.labels)
# Out:
# test batch size:  64   test steps:  112  number of classes :  7
#
# There are 7 classes: ['fearful', 'disgusted', 'angry', 'neutral', 'sad', 'surprised', 'happy']
# The class dictionary are: {'fearful': 0, 'disgusted': 1, 'angry': 2, 'neutral': 3, 'sad': 4, 'surprised': 5, 'happy': 6}
# Class count:  7
#
# X_train shape:  (64, 48, 48, 3)
# y_train shape:  (64, 7)
#
# X_test shape:  (64, 48, 48, 3)
# y_test shape:  (64, 7)
#
# train_generator sample:  40404
# validation_generator sample:  10101
# test_generator sample:  7178
#
# train_generator sample:  [0 0 0 ... 6 6 6]
# validation_generator sample:  [0 0 0 ... 6 6 6]
# test_generator sample:  [0 0 0 ... 6 6 6]

# %%
class_indices = train_generator.class_indices
class_counts = {class_name: 0 for class_name in class_indices}
num_images = train_generator.samples

batch_size = train_generator.batch_size
num_batches = len(train_generator)

for i in range(num_batches):
    batch = next(train_generator)
    images, labels = batch
    for j in range(len(labels)):
        label = npy.argmax(labels[j])  # convert one-hot encoding to integer label
        class_name = list(class_indices.keys())[list(class_indices.values()).index(label)]
        class_counts[class_name] += 1

print(class_counts)
print(f"Total number of images in train generator: {num_images}")
# Out:
# {'fearful': 5769, 'disgusted': 5774, 'angry': 5767, 'neutral': 5781, 'sad': 5773, 'surprised': 5770, 'happy': 5770}
# Total number of images in train generator: 40404

# %% [markdown]
# # Visual

# %%
import numpy as np

# %%
# Get the sample images, labels, and their filenames 
# To get the correct filename, turn off the shuffle
def plotImageWithNames(gen):
    images, labels = next(gen)
    classes = list(gen.class_indices.keys())
    
    plt.figure(figsize=(20, 30))
    length = len(labels)
    r = min(length, 32) # Menggunakan min() lebih simpel daripada if-else
    
    for i in range(r):        
        plt.subplot(7, 5, i + 1)
        
        # PERBAIKAN: Gunakan image langsung tanpa dibagi 255 lagi
        # karena generator sudah melakukan rescaling
        image = images[i] 
        
        # Jika gambar terlihat terlalu gelap/aneh karena floating point, 
        # kamu bisa memastikan nilainya klip di rentang 0-1
        image = np.clip(image, 0, 1)
        
        plt.imshow(image)
        
        index = np.argmax(labels[i])
        class_name = classes[index]
        
        plt.title(
            label=f"{class_name}", 
            color='blue', 
            fontsize=20
        )
        plt.axis('off')
    plt.show()

plotImageWithNames(train_generator)

# %% [markdown]
# # Modeling

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Asumsi target_size yang kamu gunakan (misal: 48 atau 64)
# Sesuaikan dengan variabel target_size di kode kamu
img_height = 48
img_width = 48 

def build_final_model():
    model = models.Sequential([
        layers.Input(shape=(img_height, img_width, 3)),
        
        # Block 1
        layers.Conv2D(16, (3, 3), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),

        # Block 2
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 3
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        # Block 4
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.3),

        # Full Connected
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(len(classes), activation='softmax') # Mengikuti jumlah class kamu
    ])
    
    return model

model = build_final_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 48, 48, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 48, 48, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 48, 48, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 48, 48, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 12, 12, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 12, 12, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 6, 6, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 6, 6, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 3, 3, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 7)              │         3,591 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,580,391 (6.03 MB)
#  Trainable params: 1,578,375 (6.02 MB)
#  Non-trainable params: 2,016 (7.88 KB)

# %%
# Model Architecture path
def model_arch(model_name):
    # !mkdir -p images
    # !mkdir images
    arch=IMAGE_PATH+'/fer-2013_'+model_name+'.png'
    return arch

#  TensorFlow Checkpoint save_weight uses .ckpt extension format
def checkpoint_path(model_name):
    # !mkdir models
    checkpoint_path = MODEL_PATH+"/fedav_best_model-"+model_name+".ckpt"
    return checkpoint_path

model_name = "CNN_4Block"

# %%
from tensorflow.keras.utils import plot_model

# Pastikan model sudah dibangun (misal: model = build_final_model())
plot_model(
    model,
    to_file='arsitektur_'+model_name+'.png', # Nama file yang akan disimpan
    show_shapes=True,                    # Menampilkan ukuran input/output (sangat membantu!)
    show_layer_names=True,               # Menampilkan nama layer
    show_layer_activations=True,         # Menampilkan fungsi aktivasi (ReLU, Softmax, dll)
    dpi=96                               # Kualitas gambar
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

# 1. Checkpoint: Simpan model terbaik secara otomatis
checkpoint = ModelCheckpoint(
    'best_emotion_model.keras', # Gunakan ekstensi .keras
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# 2. Learning Rate Scheduler: Menurunkan LR jika akurasi stagnan
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=0.00001,
    verbose=1
)

# Define the callback
early_stopping = EarlyStopping(
    monitor='val_loss',      # Metric to monitor
    patience=5,              # Number of epochs with no improvement
    restore_best_weights=True, # Restores model weights from the best epoch
    verbose=1
)

# Gabungkan callbacks
callbacks_list = [checkpoint, lr_scheduler, early_stopping]

# %%
# Pastikan callback ASK yang sudah diperbaiki atau checkpoint digunakan di sini
history = model.fit(
    train_generator,
    epochs=50, # Sesuaikan
    validation_data=validation_generator,
    callbacks=callbacks_list # Gunakan checkpoint agar model langsung tersimpan saat training
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.2090 - loss: 2.4083
# Epoch 1: val_accuracy improved from -inf to 0.24908, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 79s 107ms/step - accuracy: 0.2090 - loss: 2.4078 - val_accuracy: 0.2491 - val_loss: 1.9114 - learning_rate: 0.0010
# Epoch 2/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3294 - loss: 1.7470
# Epoch 2: val_accuracy improved from 0.24908 to 0.39432, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.3295 - loss: 1.7469 - val_accuracy: 0.3943 - val_loss: 1.5937 - learning_rate: 0.0010
# Epoch 3/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4229 - loss: 1.5123
# Epoch 3: val_accuracy improved from 0.39432 to 0.47243, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.4229 - loss: 1.5123 - val_accuracy: 0.4724 - val_loss: 1.4122 - learning_rate: 0.0010
# Epoch 4/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4568 - loss: 1.4306
# Epoch 4: val_accuracy did not improve from 0.47243
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.4568 - loss: 1.4306 - val_accuracy: 0.4135 - val_loss: 1.5503 - learning_rate: 0.0010
# Epoch 5/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.4850 - loss: 1.3600
# Epoch 5: val_accuracy did not improve from 0.47243
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.4850 - loss: 1.3599 - val_accuracy: 0.4703 - val_loss: 1.4645 - learning_rate: 0.0010
# Epoch 6/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5044 - loss: 1.3077
# Epoch 6: val_accuracy improved from 0.47243 to 0.52034, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.5044 - loss: 1.3077 - val_accuracy: 0.5203 - val_loss: 1.3288 - learning_rate: 0.0010
# Epoch 7/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5225 - loss: 1.2688
# Epoch 7: val_accuracy improved from 0.52034 to 0.56103, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.5225 - loss: 1.2688 - val_accuracy: 0.5610 - val_loss: 1.1550 - learning_rate: 0.0010
# Epoch 8/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5340 - loss: 1.2328
# Epoch 8: val_accuracy improved from 0.56103 to 0.56836, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.5340 - loss: 1.2328 - val_accuracy: 0.5684 - val_loss: 1.1432 - learning_rate: 0.0010
# Epoch 9/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5448 - loss: 1.2059
# Epoch 9: val_accuracy improved from 0.56836 to 0.57767, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.5448 - loss: 1.2059 - val_accuracy: 0.5777 - val_loss: 1.1164 - learning_rate: 0.0010
# Epoch 10/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5543 - loss: 1.1840
# Epoch 10: val_accuracy did not improve from 0.57767
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 94ms/step - accuracy: 0.5543 - loss: 1.1840 - val_accuracy: 0.5772 - val_loss: 1.1282 - learning_rate: 0.0010
# Epoch 11/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5592 - loss: 1.1703
# Epoch 11: val_accuracy improved from 0.57767 to 0.58370, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.5592 - loss: 1.1703 - val_accuracy: 0.5837 - val_loss: 1.0920 - learning_rate: 0.0010
# Epoch 12/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5670 - loss: 1.1421
# Epoch 12: val_accuracy improved from 0.58370 to 0.59351, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.5670 - loss: 1.1421 - val_accuracy: 0.5935 - val_loss: 1.0771 - learning_rate: 0.0010
# Epoch 13/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5820 - loss: 1.1116
# Epoch 13: val_accuracy did not improve from 0.59351
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.5820 - loss: 1.1117 - val_accuracy: 0.5907 - val_loss: 1.0902 - learning_rate: 0.0010
# Epoch 14/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5853 - loss: 1.1026
# Epoch 14: val_accuracy improved from 0.59351 to 0.61034, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.5853 - loss: 1.1026 - val_accuracy: 0.6103 - val_loss: 1.0345 - learning_rate: 0.0010
# Epoch 15/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5787 - loss: 1.1182
# Epoch 15: val_accuracy improved from 0.61034 to 0.62380, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.5787 - loss: 1.1181 - val_accuracy: 0.6238 - val_loss: 0.9973 - learning_rate: 0.0010
# Epoch 16/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5923 - loss: 1.0852
# Epoch 16: val_accuracy improved from 0.62380 to 0.62469, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 94ms/step - accuracy: 0.5923 - loss: 1.0852 - val_accuracy: 0.6247 - val_loss: 1.0061 - learning_rate: 0.0010
# Epoch 17/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5914 - loss: 1.0874
# Epoch 17: val_accuracy did not improve from 0.62469
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 94ms/step - accuracy: 0.5914 - loss: 1.0874 - val_accuracy: 0.6243 - val_loss: 0.9882 - learning_rate: 0.0010
# Epoch 18/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5968 - loss: 1.0686
# Epoch 18: val_accuracy improved from 0.62469 to 0.62924, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.5968 - loss: 1.0686 - val_accuracy: 0.6292 - val_loss: 0.9822 - learning_rate: 0.0010
# Epoch 19/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6027 - loss: 1.0515
# Epoch 19: val_accuracy improved from 0.62924 to 0.64182, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.6027 - loss: 1.0515 - val_accuracy: 0.6418 - val_loss: 0.9646 - learning_rate: 0.0010
# Epoch 20/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6072 - loss: 1.0430
# Epoch 20: val_accuracy did not improve from 0.64182
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.6072 - loss: 1.0430 - val_accuracy: 0.6169 - val_loss: 1.0153 - learning_rate: 0.0010
# Epoch 21/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6086 - loss: 1.0400
# Epoch 21: val_accuracy did not improve from 0.64182
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 94ms/step - accuracy: 0.6086 - loss: 1.0400 - val_accuracy: 0.6351 - val_loss: 0.9665 - learning_rate: 0.0010
# Epoch 22/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6144 - loss: 1.0200
# Epoch 22: val_accuracy did not improve from 0.64182
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 94ms/step - accuracy: 0.6144 - loss: 1.0200 - val_accuracy: 0.6324 - val_loss: 0.9736 - learning_rate: 0.0010
# Epoch 23/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6253 - loss: 1.0013
# Epoch 23: val_accuracy improved from 0.64182 to 0.67221, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 94ms/step - accuracy: 0.6253 - loss: 1.0013 - val_accuracy: 0.6722 - val_loss: 0.8718 - learning_rate: 2.0000e-04
# Epoch 24/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6275 - loss: 0.9824
# Epoch 24: val_accuracy did not improve from 0.67221
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.6275 - loss: 0.9824 - val_accuracy: 0.6686 - val_loss: 0.8835 - learning_rate: 2.0000e-04
# Epoch 25/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6373 - loss: 0.9649
# Epoch 25: val_accuracy did not improve from 0.67221
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6373 - loss: 0.9649 - val_accuracy: 0.6717 - val_loss: 0.8749 - learning_rate: 2.0000e-04
# Epoch 26/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6396 - loss: 0.9528
# Epoch 26: val_accuracy did not improve from 0.67221
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.6396 - loss: 0.9528 - val_accuracy: 0.6710 - val_loss: 0.8607 - learning_rate: 2.0000e-04
# Epoch 27/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6438 - loss: 0.9550
# Epoch 27: val_accuracy improved from 0.67221 to 0.67785, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6438 - loss: 0.9550 - val_accuracy: 0.6779 - val_loss: 0.8436 - learning_rate: 2.0000e-04
# Epoch 28/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6396 - loss: 0.9580
# Epoch 28: val_accuracy did not improve from 0.67785
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6396 - loss: 0.9580 - val_accuracy: 0.6687 - val_loss: 0.8771 - learning_rate: 2.0000e-04
# Epoch 29/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6418 - loss: 0.9521
# Epoch 29: val_accuracy did not improve from 0.67785
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.6418 - loss: 0.9521 - val_accuracy: 0.6769 - val_loss: 0.8545 - learning_rate: 2.0000e-04
# Epoch 30/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6428 - loss: 0.9416
# Epoch 30: val_accuracy did not improve from 0.67785
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.6428 - loss: 0.9416 - val_accuracy: 0.6777 - val_loss: 0.8467 - learning_rate: 2.0000e-04
# Epoch 31/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6456 - loss: 0.9295
# Epoch 31: val_accuracy did not improve from 0.67785
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 94ms/step - accuracy: 0.6456 - loss: 0.9295 - val_accuracy: 0.6774 - val_loss: 0.8444 - learning_rate: 4.0000e-05
# Epoch 32/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6442 - loss: 0.9395
# Epoch 32: val_accuracy did not improve from 0.67785
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.6442 - loss: 0.9395 - val_accuracy: 0.6766 - val_loss: 0.8430 - learning_rate: 4.0000e-05
# Epoch 33/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6517 - loss: 0.9283
# Epoch 33: val_accuracy improved from 0.67785 to 0.67805, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6517 - loss: 0.9283 - val_accuracy: 0.6781 - val_loss: 0.8425 - learning_rate: 4.0000e-05
# Epoch 34/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6519 - loss: 0.9302
# Epoch 34: val_accuracy improved from 0.67805 to 0.67835, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 60s 94ms/step - accuracy: 0.6519 - loss: 0.9302 - val_accuracy: 0.6783 - val_loss: 0.8407 - learning_rate: 4.0000e-05
# Epoch 35/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6457 - loss: 0.9365
# Epoch 35: val_accuracy improved from 0.67835 to 0.68726, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6457 - loss: 0.9365 - val_accuracy: 0.6873 - val_loss: 0.8376 - learning_rate: 4.0000e-05
# Epoch 36/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6550 - loss: 0.9187
# Epoch 36: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6550 - loss: 0.9188 - val_accuracy: 0.6833 - val_loss: 0.8395 - learning_rate: 4.0000e-05
# Epoch 37/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6521 - loss: 0.9230
# Epoch 37: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6521 - loss: 0.9230 - val_accuracy: 0.6767 - val_loss: 0.8420 - learning_rate: 4.0000e-05
# Epoch 38/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6513 - loss: 0.9284
# Epoch 38: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6513 - loss: 0.9284 - val_accuracy: 0.6793 - val_loss: 0.8373 - learning_rate: 4.0000e-05
# Epoch 39/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6524 - loss: 0.9204
# Epoch 39: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6524 - loss: 0.9205 - val_accuracy: 0.6844 - val_loss: 0.8344 - learning_rate: 4.0000e-05
# Epoch 40/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6495 - loss: 0.9224
# Epoch 40: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6495 - loss: 0.9224 - val_accuracy: 0.6835 - val_loss: 0.8368 - learning_rate: 4.0000e-05
# Epoch 41/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6497 - loss: 0.9325
# Epoch 41: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 58s 92ms/step - accuracy: 0.6497 - loss: 0.9325 - val_accuracy: 0.6844 - val_loss: 0.8344 - learning_rate: 4.0000e-05
# Epoch 42/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6462 - loss: 0.9275
# Epoch 42: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6462 - loss: 0.9275 - val_accuracy: 0.6826 - val_loss: 0.8295 - learning_rate: 4.0000e-05
# Epoch 43/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6499 - loss: 0.9246
# Epoch 43: val_accuracy did not improve from 0.68726
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 58s 91ms/step - accuracy: 0.6499 - loss: 0.9246 - val_accuracy: 0.6797 - val_loss: 0.8353 - learning_rate: 4.0000e-05
# Epoch 44/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6564 - loss: 0.9141
# Epoch 44: val_accuracy improved from 0.68726 to 0.68795, saving model to best_emotion_model.keras
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 58s 92ms/step - accuracy: 0.6564 - loss: 0.9141 - val_accuracy: 0.6880 - val_loss: 0.8276 - learning_rate: 4.0000e-05
# Epoch 45/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6518 - loss: 0.9248
# Epoch 45: val_accuracy did not improve from 0.68795
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6518 - loss: 0.9248 - val_accuracy: 0.6777 - val_loss: 0.8402 - learning_rate: 4.0000e-05
# Epoch 46/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6510 - loss: 0.9207
# Epoch 46: val_accuracy did not improve from 0.68795
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 58s 92ms/step - accuracy: 0.6510 - loss: 0.9207 - val_accuracy: 0.6819 - val_loss: 0.8313 - learning_rate: 4.0000e-05
# Epoch 47/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6559 - loss: 0.9127
# Epoch 47: val_accuracy did not improve from 0.68795
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 58s 92ms/step - accuracy: 0.6559 - loss: 0.9127 - val_accuracy: 0.6853 - val_loss: 0.8236 - learning_rate: 4.0000e-05
# Epoch 48/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6564 - loss: 0.9152
# Epoch 48: val_accuracy did not improve from 0.68795
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6564 - loss: 0.9152 - val_accuracy: 0.6846 - val_loss: 0.8285 - learning_rate: 4.0000e-05
# Epoch 49/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6531 - loss: 0.9134
# Epoch 49: val_accuracy did not improve from 0.68795
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 58s 91ms/step - accuracy: 0.6531 - loss: 0.9134 - val_accuracy: 0.6824 - val_loss: 0.8368 - learning_rate: 4.0000e-05
# Epoch 50/50
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6562 - loss: 0.9126
# Epoch 50: val_accuracy did not improve from 0.68795
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1e-05.
# 632/632 ━━━━━━━━━━━━━━━━━━━━ 59s 93ms/step - accuracy: 0.6562 - loss: 0.9126 - val_accuracy: 0.6838 - val_loss: 0.8284 - learning_rate: 4.0000e-05
# Restoring model weights from the end of the best epoch: 47.

# %% [markdown]
# # Evaluasi

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))

    # Plot Akurasi
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini setelah model.fit selesai
plot_training_history(history)

# %%
import numpy as np

def test_and_visualize_predictions(model, generator, classes):
    images, labels = next(generator)
    predictions = model.predict(images)
    
    plt.figure(figsize=(15, 15))
    
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        
        # --- PERBAIKAN VISUALISASI ---
        # Memastikan data dalam format yang benar untuk imshow
        img = images[i]
        if img.max() > 1.0:
            img = img / 255.0
        plt.imshow(img)
        # -----------------------------

        actual_idx = np.argmax(labels[i])
        pred_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_idx] * 100
        
        # Mengambil nama kelas (bukan index) untuk judul
        actual_name = classes[actual_idx]
        pred_name = classes[pred_idx]
        
        title = f"Actual: {actual_name}\nPred: {pred_name} ({confidence:.1f}%)"
        title_color = 'green' if actual_idx == pred_idx else 'red'
        
        plt.title(title, color=title_color)
        plt.axis('off')
        
    plt.tight_layout()
    plt.show()

# %%
# Panggil fungsi ini untuk uji coba
test_and_visualize_predictions(model, test_generator_shuffled, classes)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def show_confusion_matrix(model, generator, classes):
    # Penting: Reset generator agar mulai dari awal
    generator.reset()
    
    # Ambil semua prediksi dari generator (shuffle harus False di sini)
    Y_pred = model.predict(generator)
    y_pred = np.argmax(Y_pred, axis=1)
    
    # Ambil label asli
    y_true = generator.classes
    
    # Hitung Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=classes, yticklabels=classes)
    plt.title('Confusion Matrix')
    plt.ylabel('Actual Label')
    plt.xlabel('Predicted Label')
    plt.show()
    
    # Print Classification Report
    print(classification_report(y_true, y_pred, target_names=classes))

# %%
# Gunakan test_generator (yang shuffle=False) untuk ini
show_confusion_matrix(model, test_generator, classes)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 56s 489ms/step
#               precision    recall  f1-score   support
#
#      fearful       0.54      0.36      0.43      1024
#    disgusted       0.48      0.77      0.59       111
#        angry       0.56      0.58      0.57       958
#      neutral       0.54      0.73      0.62      1233
#          sad       0.56      0.45      0.50      1247
#    surprised       0.70      0.83      0.76       831
#        happy       0.88      0.83      0.86      1774
#
#     accuracy                           0.65      7178
#    macro avg       0.61      0.65      0.62      7178
# weighted avg       0.65      0.65      0.64      7178

# %%
# Langsung uji model yang sudah ada
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.5223 - loss: 1.2141
# Test Loss: 0.96415776014328, Test Accuracy: 0.6455837488174438

# %%
model.save('CNN-4Block.keras')

# %%
model.save('CNN-4Block.h5')
